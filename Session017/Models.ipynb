# %% [markdown]
# # Models Informations

# %% [markdown]
# Scikit-learn provides several classification models that can handle categorical data. Here are a few examples:
#
# # Categorical Naive Bayes (CategoricalNB):
# This model is suitable for classification with discrete features that are categorically distributed. It's similar to MultinomialNB but can handle categorical features with more than two categories.
#
# # Bernoulli Naive Bayes (BernoulliNB):
# This model is suitable for binary features (i.e., features that have only two possible values). It's similar to MultinomialNB but can handle binary features.
#
# # Logistic Regression (LogisticRegression):
# This model is suitable for binary classification problems. It's a linear model that uses logistic function to predict the probability of the positive class.
#
# # Decision Trees (DecisionTreeClassifier):
# This model is suitable for classification problems with both categorical and numerical features. It works by recursively partitioning the data into smaller subsets based on the features.
#
# # Random Forests (RandomForestClassifier):
# This model is an ensemble of decision trees. It's suitable for classification problems with both categorical and numerical features.
#
# # Support Vector Machines (SVC):
# This model is suitable for classification problems with both categorical and numerical features. It works by finding the hyperplane that maximally separates the classes.
#
# # K-Nearest Neighbors (KNeighborsClassifier):
# This model is suitable for classification problems with both categorical and numerical features. It works by finding the k most similar instances to a new instance and using their labels to predict the label of the new instance.

# %% [markdown]
# # MODEL CODE EXAMPLES

# %%
from sklearn.naive_bayes import CategoricalNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

class MyModel:
    def __init__(self, model_type):
        self.vectorizer = CountVectorizer()
        if model_type == "CategoricalNB":
            self.model = CategoricalNB()
        elif model_type == "BernoulliNB":
            self.model = BernoulliNB()
        elif model_type == "LogisticRegression":
            self.model = LogisticRegression()
        elif model_type == "DecisionTreeClassifier":
            self.model = DecisionTreeClassifier()
        elif model_type == "RandomForestClassifier":
            self.model = RandomForestClassifier()
        elif model_type == "SVC":
            self.model = SVC()
        elif model_type == "KNeighborsClassifier":
            self.model = KNeighborsClassifier()

    def train(self, training_data):
        names, genders = zip(*training_data)
        X = self.vectorizer.fit_transform(names)
        y = genders
        self.model.fit(X, y)

    def predict(self, name):
        X = self.vectorizer.transform([name])
        return self.model.predict(X)[0]

    def learn(self, name, gender):
        X = self.vectorizer.transform([name])
        self.model.partial_fit(X, [gender], classes=["M", "F", "NEUTRAL"])

#model = MyModel("LogisticRegression") # Instantiation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 40
#      37         X = self.vectorizer.transform([name])
#      38         self.model.partial_fit(X, [gender], classes=["M", "F", "NEUTRAL"])
# ---> 40 model = MyModel("LogisticRegression") # Instantiation
#
# Cell In[7], line 10, in MyModel.__init__(self, model_type)
#       9 def __init__(self, model_type):
# ---> 10     self.vectorizer = CountVectorizer()
#      11     if model_type == "CategoricalNB":
#      12         self.model = CategoricalNB()
#
# NameError: name 'CountVectorizer' is not defined

# %%
import pickle

file = open('train_raw_data.pkl', 'rb')
data = pickle.load(file)
file.close()


for item in data:
    print(item)
# Out:
# ('Aaban', 'M', 1.0)
# ('Aabha', 'F', 1.0)
# ('Aabid', 'M', 1.0)
# ('Aabriella', 'F', 1.0)
# ('Aada', 'F', 1.0)
# ('Aadam', 'M', 1.0)
# ('Aadan', 'M', 1.0)
# ('Aadarsh', 'M', 1.0)
# ('Aaden', 'M', 0.998814604)
# ('Aadesh', 'M', 1.0)
# ('Aadhav', 'M', 1.0)
# ('Aadhavan', 'M', 1.0)
# ('Aadhi', 'M', 1.0)
# ('Aadhira', 'F', 1.0)
# ('Aadhvik', 'M', 1.0)
# ('Aadhya', 'F', 1.0)
# ('Aadhyan', 'M', 1.0)
# ('Aadi', 'M', 0.977961433)
# ('Aadian', 'M', 1.0)
# ('Aadil', 'M', 1.0)
# ('Aadin', 'M', 1.0)
# ('Aadish', 'M', 1.0)
# ('Aadison', 'F', 1.0)
# ('Aadit', 'M', 1.0)
# ('Aadith', 'M', 1.0)
# ('Aadithya', 'M', 1.0)
# ('Aaditri', 'F', 1.0)
# ('Aaditya', 'M', 1.0)
# ('Aadiv', 'M', 1.0)
# ('Aadon', 'M', 1.0)
# ('Aadrian', 'M', 1.0)
# ('Aadrika', 'F', 1.0)
# ('Aadrit', 'M', 1.0)
# ('Aadvik', 'M', 1.0)
# ('Aadvika', 'F', 1.0)
# ('Aadya', 'F', 1.0)
# ('Aadyn', 'M', 0.9629629629629628)
# ('Aafia', 'F', 1.0)
# ('Aafreen', 'F', 1.0)
# ('Aagam', 'M', 1.0)
# ('Aage', 'M', 1.0)
# ('Aagot', 'F', 1.0)
# ('Aahaan', 'M', 1.0)
# ('Aahan', 'M', 1.0)
# ('Aahana', 'F', 1.0)
# ('Aahil', 'M', 1.0)
# ('Aahir', 'M', 1.0)
# ('Aahliyah', 'F', 1.0)
# ('Aahna', 'F', 1.0)
# ('Aahron', 'M', 1.0)
# ('Aaidan', 'M', 1.0)
# ('Aaiden', 'M', 1.0)
# ('Aaidyn', 'M', 1.0)
# ('Aaila', 'F', 1.0)
# ('Aailiyah', 'F', 1.0)
# ('Aailyah', 'F', 1.0)
# ('Aaima', 'F', 1.0)
# ('Aaira', 'F', 1.0)
# ('Aairah', 'F', 1.0)
# ('Aaisha', 'F', 1.0)
# ('Aaishah', 'F', 1.0)
# ('Aaiyana', 'F', 1.0)
# ('Aaiza', 'F', 1.0)
# ('Aaja', 'F', 1.0)
# ('Aajah', 'F', 1.0)
# ('Aajaylah', 'F', 1.0)
# ('Aajon', 'M', 1.0)
# ('Aakanksha', 'F', 1.0)
# ('Aakarsh', 'M', 1.0)
# ('Aakash', 'M', 1.0)
# ('Aakeem', 'M', 1.0)
# ('Aakilah', 'F', 1.0)
# ('Aakira', 'F', 1.0)
# ('Aakiyah', 'F', 1.0)
# ('Aakriti', 'F', 1.0)
# ('Aala', 'F', 1.0)
# ('Aalaiya', 'F', 1.0)
# ('Aalaiyah', 'F', 1.0)
# ('Aalana', 'F', 1.0)
# ('Aalanah', 'F', 1.0)
# ('Aalani', 'F', 1.0)
# ('Aalap', 'M', 1.0)
# ('Aalaya', 'F', 1.0)
# ('Aalayah', 'F', 1.0)
# ('Aalayiah', 'F', 1.0)
# ('Aalayjah', 'F', 1.0)
# ('Aalayna', 'F', 1.0)
# ('Aalaysha', 'F', 1.0)
# ('Aalaysia', 'F', 1.0)
# ('Aalea', 'F', 1.0)
# ('Aaleah', 'F', 1.0)
# ('Aaleahya', 'F', 1.0)
# ('Aaleena', 'F', 1.0)
# ('Aaleeya', 'F', 1.0)
# ('Aaleeyah', 'F', 1.0)
# ('Aaleiah', 'F', 1.0)
# ('Aaleigha', 'F', 1.0)
# ('Aaleiyah', 'F', 1.0)
# ('Aalena', 'F', 1.0)
# ('Aalexis', 'F', 1.0)
# ('Aalexus', 'F', 1.0)
# ('Aaleya', 'F', 1.0)
# ('Aaleyah', 'F', 1.0)
# ('Aali', 'M', 1.0)
# ('Aalia', 'F', 1.0)
# ('Aaliah', 'F', 1.0)
# ('Aaliana', 'F', 1.0)
# ('Aalias', 'M', 1.0)
# ('Aaliayah', 'F', 1.0)
# ('Aaliayh', 'F', 1.0)
# ('Aalicia', 'F', 1.0)
# ('Aaliha', 'F', 1.0)
# ('Aalijah', 'M', 0.5910652920962199)
# ('Aalim', 'M', 1.0)
# ('Aalimah', 'F', 1.0)
# ('Aalina', 'F', 1.0)
# ('Aalinah', 'F', 1.0)
# ('Aalisa', 'F', 1.0)
# ('Aalisha', 'F', 1.0)
# ('Aalivia', 'F', 1.0)
# ('Aaliya', 'F', 1.0)
# ('Aaliyaa', 'F', 1.0)
# ('Aaliyah', 'F', 0.9988101445206486)
# ('Aaliyaha', 'F', 1.0)
# ('Aaliyahmarie', 'F', 1.0)
# ('Aaliyahrose', 'F', 1.0)
# ('Aaliyan', 'F', 1.0)
# ('Aaliyana', 'F', 1.0)
# ('Aaliyanna', 'F', 1.0)
# ('Aaliyha', 'F', 1.0)
# ('Aaliyiah', 'F', 1.0)
# ('Aalliyah', 'F', 1.0)
# ('Aallyah', 'F', 1.0)
# ('Aalok', 'M', 1.0)
# ('Aalon', 'M', 1.0)
# ('Aalya', 'F', 1.0)
# ('Aalyah', 'F', 1.0)
# ('Aalycia', 'F', 1.0)
# ('Aalyha', 'F', 1.0)
# ('Aalyia', 'F', 1.0)
# ('Aalyiah', 'F', 1.0)
# ('Aalyna', 'F', 1.0)
# ('Aalysia', 'F', 1.0)
# ('Aalyssa', 'F', 1.0)
# ('Aalyvia', 'F', 1.0)
# ('Aamanda', 'F', 1.0)
# ('Aamanee', 'F', 1.0)
# ('Aamani', 'F', 1.0)
# ('Aamar', 'M', 1.0)
# ('Aamari', 'M', 0.5555555555555556)
# ('Aamarion', 'M', 1.0)
# ('Aamaya', 'F', 1.0)
# ('Aamber', 'F', 1.0)
# ('Aamena', 'F', 1.0)
# ('Aamer', 'M', 1.0)
# ('Aamia', 'F', 1.0)
# ('Aamil', 'M', 1.0)
# ('Aamilah', 'F', 1.0)
# ('Aamina', 'F', 1.0)
# ('Aaminah', 'F', 1.0)
# ('Aamir', 'M', 0.9961977186311788)
# ('Aamira', 'F', 1.0)
# ('Aamirah', 'F', 1.0)
# ('Aamiya', 'F', 1.0)
# ('Aamiyah', 'F', 1.0)
# ('Aamna', 'F', 1.0)
# ('Aamoni', 'F', 1.0)
# ('Aamori', 'F', 1.0)
# ('Aamya', 'F', 1.0)
# ('Aamyah', 'F', 1.0)
# ('Aana', 'F', 1.0)
# ('Aanand', 'M', 1.0)
# ('Aanav', 'M', 1.0)
# ('Aanaya', 'F', 1.0)
# ('Aanchal', 'F', 1.0)
# ('Aania', 'F', 1.0)
# ('Aaniah', 'F', 1.0)
# ('Aanijah', 'F', 1.0)
# ('Aanika', 'F', 1.0)
# ('Aanisah', 'F', 1.0)
# ('Aaniya', 'F', 1.0)
# ('Aaniyah', 'F', 1.0)
# ('Aaniylah', 'F', 1.0)
# ('Aansh', 'M', 1.0)
# ('Aanshi', 'F', 1.0)
# ('Aanvi', 'F', 1.0)
# ('Aanya', 'F', 1.0)
# ('Aanyah', 'F', 1.0)
# ('Aanyla', 'F', 1.0)
# ('Aapri', 'F', 1.0)
# ('Aaqib', 'M', 1.0)
# ('Aaqil', 'M', 1.0)
# ('Aara', 'F', 1.0)
# ('Aarabella', 'F', 1.0)
# ('Aarabhi', 'F', 1.0)
# ('Aaradhana', 'F', 1.0)
# ('Aaradhy', 'M', 1.0)
# ('Aaradhya', 'F', 1.0)
# ('Aaraiz', 'M', 1.0)
# ('Aaralyn', 'F', 1.0)
# ('Aaralynn', 'F', 1.0)
# ('Aaran', 'M', 1.0)
# ('Aaraon', 'M', 1.0)
# ('Aaratrika', 'F', 1.0)
# ('Aarav', 'M', 1.0)
# ('Aaravi', 'F', 1.0)
# ('Aaraya', 'F', 1.0)
# ('Aaren', 'M', 0.7238001958863859)
# ('Aareon', 'M', 0.7674418604651163)
# ('Aareona', 'F', 1.0)
# ('Aari', 'F', 0.6428571428571429)
# ('Aaria', 'F', 1.0)
# ('Aariah', 'F', 1.0)
# ('Aarian', 'M', 0.6496350364963503)
# ('Aariana', 'F', 1.0)
# ('Aarianna', 'F', 1.0)
# ('Aarib', 'M', 1.0)
# ('Aaric', 'M', 1.0)
# ('Aarica', 'F', 1.0)
# ('Aarick', 'M', 1.0)
# ('Aarie', 'F', 1.0)
# ('Aariel', 'F', 1.0)
# ('Aarielle', 'F', 1.0)
# ('Aarien', 'M', 1.0)
# ('Aarik', 'M', 1.0)
# ('Aarika', 'F', 1.0)
# ('Aariketh', 'M', 1.0)
# ('Aarilyn', 'F', 1.0)
# ('Aarilynn', 'F', 1.0)
# ('Aarin', 'M', 0.6130718954248366)
# ('Aarini', 'F', 1.0)
# ('Aarion', 'M', 0.7610921501706485)
# ('Aariona', 'F', 1.0)
# ('Aarionna', 'F', 1.0)
# ('Aaris', 'F', 0.5396825396825397)
# ('Aarish', 'M', 1.0)
# ('Aarit', 'M', 1.0)
# ('Aariv', 'M', 1.0)
# ('Aariya', 'F', 1.0)
# ('Aariyah', 'F', 1.0)
# ('Aariyan', 'M', 1.0)
# ('Aariyana', 'F', 1.0)
# ('Aariyanna', 'F', 1.0)
# ('Aariyona', 'F', 1.0)
# ('Aariyonna', 'F', 1.0)
# ('Aariz', 'M', 1.0)
# ('Aarjav', 'M', 1.0)
# ('Aarn', 'M', 1.0)
# ('Aarna', 'F', 1.0)
# ('Aarnav', 'M', 1.0)
# ('Aarnavi', 'F', 1.0)
# ('Aarne', 'M', 1.0)
# ('Aaro', 'M', 1.0)
# ('Aaroh', 'M', 1.0)
# ('Aarohan', 'M', 1.0)
# ('Aarohi', 'F', 1.0)
# ('Aarolyn', 'F', 1.0)
# ('Aaron', 'M', 0.9924861393515004)
# ('Aarona', 'F', 1.0)
# ('Aaronae', 'F', 1.0)
# ('Aaronda', 'F', 1.0)
# ('Aaronette', 'F', 1.0)
# ('Aaronisha', 'F', 1.0)
# ('Aaronjacob', 'M', 1.0)
# ('Aaronjames', 'M', 1.0)
# ('Aaronjohn', 'M', 1.0)
# ('Aaronjoseph', 'M', 1.0)
# ('Aaronjosh', 'M', 1.0)
# ('Aaronjoshua', 'M', 1.0)
# ('Aaronlee', 'M', 1.0)
# ('Aaronmichael', 'M', 1.0)
# ('Aaronn', 'M', 1.0)
# ('Aaroosh', 'M', 1.0)
# ('Aarren', 'M', 1.0)
# ('Aarron', 'M', 1.0)
# ('Aarsh', 'M', 1.0)
# ('Aarshi', 'F', 1.0)
# ('Aarshiya', 'F', 1.0)
# ('Aarthi', 'F', 1.0)
# ('Aarti', 'F', 1.0)
# ('Aaruhi', 'F', 1.0)
# ('Aarush', 'M', 1.0)
# ('Aarushi', 'F', 1.0)
# ('Aarvi', 'F', 1.0)
# ('Aarvin', 'M', 1.0)
# ('Aarya', 'F', 0.7997169143665959)
# ('Aaryah', 'F', 1.0)
# ('Aaryahi', 'F', 1.0)
# ('Aaryan', 'M', 0.994540491355778)
# ('Aaryana', 'F', 1.0)
# ('Aaryanna', 'F', 1.0)
# ('Aaryash', 'M', 1.0)
# ('Aaryav', 'M', 1.0)
# ('Aaryn', 'F', 0.6101694915254238)
# ('Aaryon', 'M', 1.0)
# ('Aaryona', 'F', 1.0)
# ('Aarza', 'F', 1.0)
# ('Aaser', 'M', 1.0)
# ('Aasha', 'F', 1.0)
# ('Aashana', 'F', 1.0)
# ('Aashay', 'M', 1.0)
# ('Aashi', 'F', 1.0)
# ('Aashia', 'F', 1.0)
# ('Aashika', 'F', 1.0)
# ('Aashini', 'F', 1.0)
# ('Aashir', 'M', 1.0)
# ('Aashirya', 'F', 1.0)
# ('Aashish', 'M', 1.0)
# ('Aashita', 'F', 1.0)
# ('Aashiyana', 'F', 1.0)
# ('Aashka', 'F', 1.0)
# ('Aashman', 'M', 1.0)
# ('Aashna', 'F', 1.0)
# ('Aashni', 'F', 1.0)
# ('Aashray', 'M', 1.0)
# ('Aashrita', 'F', 1.0)
# ('Aashrith', 'M', 1.0)
# ('Aashritha', 'F', 1.0)
# ('Aashvi', 'F', 1.0)
# ('Aasia', 'F', 1.0)
# ('Aasim', 'M', 1.0)
# ('Aasin', 'M', 1.0)
# ('Aasir', 'M', 1.0)
# ('Aasiya', 'F', 1.0)
# ('Aasiyah', 'F', 1.0)
# ('Aason', 'M', 1.0)
# ('Aastha', 'F', 1.0)
# ('Aathan', 'M', 1.0)
# ('Aatif', 'M', 1.0)
# ('Aatish', 'M', 1.0)
# ('Aava', 'F', 1.0)
# ('Aavah', 'F', 1.0)
# ('Aavash', 'M', 1.0)
# ('Aaven', 'M', 1.0)
# ('Aavi', 'M', 1.0)
# ('Aavin', 'M', 1.0)
# ('Aavion', 'M', 1.0)
# ('Aavya', 'F', 1.0)
# ('Aavyan', 'M', 1.0)
# ('Aavyn', 'M', 0.5454545454545454)
# ('Aaya', 'F', 1.0)
# ('Aayaan', 'M', 1.0)
# ('Aayah', 'F', 1.0)
# ('Aayam', 'M', 1.0)
# ('Aayan', 'M', 1.0)
# ('Aayana', 'F', 1.0)
# ('Aayanah', 'F', 1.0)
# ('Aayanna', 'F', 1.0)
# ('Aayansh', 'M', 1.0)
# ('Aayat', 'F', 1.0)
# ('Aaydan', 'M', 1.0)
# ('Aayden', 'M', 0.9958053691275168)
# ('Aayla', 'F', 1.0)
# ('Aaylah', 'F', 1.0)
# ('Aayliah', 'F', 1.0)
# ('Aayra', 'F', 1.0)
# ('Aayu', 'M', 1.0)
# ('Aayush', 'M', 1.0)
# ('Aayusha', 'F', 1.0)
# ('Aayushi', 'F', 1.0)
# ('Aazan', 'M', 1.0)
# ('Aazim', 'M', 1.0)
# ('Aaziyah', 'F', 1.0)
# ('Ab', 'M', 1.0)
# ('Aba', 'F', 0.8148148148148148)
# ('Abaan', 'M', 1.0)
# ('Abad', 'M', 1.0)
# ('Abagael', 'F', 1.0)
# ('Abagail', 'F', 1.0)
# ('Abagaile', 'F', 1.0)
# ('Abagale', 'F', 1.0)
# ('Abagayle', 'F', 1.0)
# ('Abaigael', 'F', 1.0)
# ('Abaigail', 'F', 1.0)
# ('Abaigeal', 'F', 1.0)
# ('Aban', 'M', 1.0)
# ('Abanoub', 'M', 1.0)
# ('Abas', 'M', 1.0)
# ('Abasi', 'M', 1.0)
# ('Abass', 'M', 1.0)
# ('Abayomi', 'M', 1.0)
# ('Abb', 'M', 1.0)
# ('Abba', 'M', 0.85)
# ('Abbaas', 'M', 1.0)
# ('Abbagail', 'F', 1.0)
# ('Abbagale', 'F', 1.0)
# ('Abbagayle', 'F', 1.0)
# ('Abbas', 'M', 1.0)
# ('Abbe', 'F', 1.0)
# ('Abbee', 'F', 1.0)
# ('Abbegail', 'F', 1.0)
# ('Abbegale', 'F', 1.0)
# ('Abbegayle', 'F', 1.0)
# ('Abbey', 'F', 0.9979335183326444)
# ('Abbeygail', 'F', 1.0)
# ('Abbeygale', 'F', 1.0)
# ('Abbi', 'F', 1.0)
# ('Abbie', 'F', 0.984821595367084)
# ('Abbiegail', 'F', 1.0)
# ('Abbiegale', 'F', 1.0)
# ('Abbiegayle', 'F', 1.0)
# ('Abbigael', 'F', 1.0)
# ('Abbigail', 'F', 0.9995481655521417)
# ('Abbigaile', 'F', 1.0)
# ('Abbigal', 'F', 1.0)
# ('Abbigale', 'F', 1.0)
# ('Abbigayl', 'F', 1.0)
# ('Abbigayle', 'F', 1.0)
# ('Abbilyn', 'F', 1.0)
# ('Abbot', 'M', 1.0)
# ('Abbott', 'M', 0.9733924611973392)
# ('Abbra', 'F', 1.0)
# ('Abbriella', 'F', 1.0)
# ('Abbrielle', 'F', 1.0)
# ('Abby', 'F', 0.9967859933233896)
# ('Abbye', 'F', 1.0)
# ('Abbygael', 'F', 1.0)
# ('Abbygail', 'F', 1.0)
# ('Abbygaile', 'F', 1.0)
# ('Abbygale', 'F', 1.0)
# ('Abbygayl', 'F', 1.0)
# ('Abbygayle', 'F', 1.0)
# ('Abbylynn', 'F', 1.0)
# ('Abcde', 'F', 1.0)
# ('Abd', 'M', 1.0)
# ('Abdala', 'M', 1.0)
# ('Abdalah', 'M', 1.0)
# ('Abdalla', 'M', 1.0)
# ('Abdallah', 'M', 1.0)
# ('Abdalrahman', 'M', 1.0)
# ('Abdalrhman', 'M', 1.0)
# ('Abdel', 'M', 1.0)
# ('Abdelaziz', 'M', 1.0)
# ('Abdelhadi', 'M', 1.0)
# ('Abdelkareem', 'M', 1.0)
# ('Abdelkarim', 'M', 1.0)
# ('Abdellah', 'M', 1.0)
# ('Abdelrahman', 'M', 1.0)
# ('Abdelrhman', 'M', 1.0)
# ('Abderrahman', 'M', 1.0)
# ('Abdi', 'M', 0.9612403100775194)
# ('Abdias', 'M', 1.0)
# ('Abdiasis', 'M', 1.0)
# ('Abdiaziz', 'M', 1.0)
# ('Abdiel', 'M', 1.0)
# ('Abdifatah', 'M', 1.0)
# ('Abdihafid', 'M', 1.0)
# ('Abdihakim', 'M', 1.0)
# ('Abdihamid', 'M', 1.0)
# ('Abdikadir', 'M', 1.0)
# ('Abdikarim', 'M', 1.0)
# ('Abdikhaliq', 'M', 1.0)
# ('Abdilahi', 'M', 1.0)
# ('Abdimalik', 'M', 1.0)
# ('Abdinajib', 'M', 1.0)
# ('Abdinasir', 'M', 1.0)
# ('Abdiqani', 'M', 1.0)
# ('Abdirahim', 'M', 1.0)
# ('Abdirahin', 'M', 1.0)
# ('Abdirahman', 'M', 1.0)
# ('Abdirashid', 'M', 1.0)
# ('Abdirisaq', 'M', 1.0)
# ('Abdirizak', 'M', 1.0)
# ('Abdisalam', 'M', 1.0)
# ('Abdisalan', 'M', 1.0)
# ('Abdisamad', 'M', 1.0)
# ('Abdishakur', 'M', 1.0)
# ('Abdiwahab', 'M', 1.0)
# ('Abdiwali', 'M', 1.0)
# ('Abdo', 'M', 1.0)
# ('Abdon', 'M', 1.0)
# ('Abdou', 'M', 1.0)
# ('Abdoul', 'M', 1.0)
# ('Abdoulaye', 'M', 1.0)
# ('Abdoulaziz', 'M', 1.0)
# ('Abdoulie', 'M', 1.0)
# ('Abdourahman', 'M', 1.0)
# ('Abdourahmane', 'M', 1.0)
# ('Abdrahman', 'M', 1.0)
# ('Abdrew', 'M', 1.0)
# ('Abdu', 'M', 1.0)
# ('Abdual', 'M', 1.0)
# ('Abduallah', 'M', 1.0)
# ('Abduel', 'M', 1.0)
# ('Abdul', 'M', 1.0)
# ('Abdula', 'M', 1.0)
# ('Abdulah', 'M', 1.0)
# ('Abdulahad', 'M', 1.0)
# ('Abdulahi', 'M', 1.0)
# ('Abdulai', 'M', 1.0)
# ('Abdulaye', 'M', 1.0)
# ('Abdulazeem', 'M', 1.0)
# ('Abdulazeez', 'M', 1.0)
# ('Abdulaziz', 'M', 1.0)
# ('Abdulbari', 'M', 1.0)
# ('Abdulbasit', 'M', 1.0)
# ('Abdule', 'M', 1.0)
# ('Abdulelah', 'M', 1.0)
# ('Abdulhadi', 'M', 1.0)
# ('Abdulhakeem', 'M', 1.0)
# ('Abdulhakim', 'M', 1.0)
# ('Abdulhalim', 'M', 1.0)
# ('Abdulhameed', 'M', 1.0)
# ('Abdulhamid', 'M', 1.0)
# ('Abduljabbar', 'M', 1.0)
# ('Abduljaleel', 'M', 1.0)
# ('Abduljalil', 'M', 1.0)
# ('Abdulkadir', 'M', 1.0)
# ('Abdulkareem', 'M', 1.0)
# ('Abdulkarim', 'M', 1.0)
# ('Abdulkhaliq', 'M', 1.0)
# ('Abdull', 'M', 1.0)
# ('Abdulla', 'M', 1.0)
# ('Abdullah', 'M', 1.0)
# ('Abdullahi', 'M', 1.0)
# ('Abdullatif', 'M', 1.0)
# ('Abdulloh', 'M', 1.0)
# ('Abdulmajeed', 'M', 1.0)
# ('Abdulmajid', 'M', 1.0)
# ('Abdulmalek', 'M', 1.0)
# ('Abdulmalik', 'M', 1.0)
# ('Abdulmohsen', 'M', 1.0)
# ('Abdulnasir', 'M', 1.0)
# ('Abdulqadir', 'M', 1.0)
# ('Abdulraheem', 'M', 1.0)
# ('Abdulrahim', 'M', 1.0)
# ('Abdulrahman', 'M', 1.0)
# ('Abdulrazaq', 'M', 1.0)
# ('Abdulrehman', 'M', 1.0)
# ('Abdulrhman', 'M', 1.0)
# ('Abdulsalam', 'M', 1.0)
# ('Abdulsamad', 'M', 1.0)
# ('Abdulwadud', 'M', 1.0)
# ('Abdulwahab', 'M', 1.0)
# ('Abdulwahid', 'M', 1.0)
# ('Abdur', 'M', 1.0)
# ('Abdurahman', 'M', 1.0)
# ('Abdurahmon', 'M', 1.0)
# ('Abdurraheem', 'M', 1.0)
# ('Abdurrahim', 'M', 1.0)
# ('Abdurrahmaan', 'M', 1.0)
# ('Abdurrahman', 'M', 1.0)
# ('Abdurrehman', 'M', 1.0)
# ('Abdussamad', 'M', 1.0)
# ('Abe', 'M', 1.0)
# ('Abeal', 'M', 1.0)
# ('Abed', 'M', 1.0)
# ('Abedallah', 'M', 1.0)
# ('Abedalrahman', 'M', 1.0)
# ('Abednego', 'M', 1.0)
# ('Abeeha', 'F', 1.0)
# ('Abeer', 'F', 0.9514018691588784)
# ('Abeera', 'F', 1.0)
# ('Abegail', 'F', 1.0)
# ('Abegale', 'F', 1.0)
# ('Abegayle', 'F', 1.0)
# ('Abel', 'M', 0.9975946948409576)
# ('Abela', 'F', 1.0)
# ('Abelardo', 'M', 1.0)
# ('Abelina', 'F', 1.0)
# ('Abelino', 'M', 1.0)
# ('Abell', 'M', 0.6875)
# ('Abella', 'F', 1.0)
# ('Abem', 'M', 1.0)
# ('Aben', 'M', 1.0)
# ('Abena', 'F', 1.0)
# ('Abenezer', 'M', 1.0)
# ('Abeni', 'F', 1.0)
# ('Aber', 'F', 1.0)
# ('Aberdeen', 'F', 1.0)
# ('Aberham', 'M', 1.0)
# ('Abernathy', 'F', 1.0)
# ('Abert', 'M', 1.0)
# ('Abery', 'F', 1.0)
# ('Abey', 'F', 0.6296296296296297)
# ('Abgail', 'F', 1.0)
# ('Abha', 'F', 1.0)
# ('Abhay', 'M', 1.0)
# ('Abheek', 'M', 1.0)
# ('Abhi', 'M', 1.0)
# ('Abhigna', 'F', 1.0)
# ('Abhijay', 'M', 1.0)
# ('Abhijeet', 'M', 1.0)
# ('Abhijit', 'M', 1.0)
# ('Abhijot', 'M', 1.0)
# ('Abhik', 'M', 1.0)
# ('Abhilash', 'M', 1.0)
# ('Abhimanyu', 'M', 1.0)
# ('Abhinav', 'M', 1.0)
# ('Abhinay', 'M', 1.0)
# ('Abhinaya', 'F', 1.0)
# ('Abhiraam', 'M', 1.0)
# ('Abhiraj', 'M', 1.0)
# ('Abhiram', 'M', 1.0)
# ('Abhirup', 'M', 1.0)
# ('Abhishek', 'M', 1.0)
# ('Abhyuday', 'M', 1.0)
# ('Abi', 'F', 0.954639175)
# ('Abia', 'F', 1.0)
# ('Abiageal', 'F', 1.0)
# ('Abiah', 'F', 1.0)
# ('Abian', 'M', 1.0)
# ('Abianna', 'F', 1.0)
# ('Abibail', 'F', 1.0)
# ('Abid', 'M', 1.0)
# ('Abida', 'F', 1.0)
# ('Abidah', 'F', 1.0)
# ('Abidan', 'M', 1.0)
# ('Abie', 'M', 0.9049645390070922)
# ('Abiegail', 'F', 1.0)
# ('Abiel', 'M', 0.9774066797642436)
# ('Abiela', 'F', 1.0)
# ('Abiella', 'F', 1.0)
# ('Abiezer', 'M', 1.0)
# ('Abigael', 'F', 0.9968071519795658)
# ('Abigaelle', 'F', 1.0)
# ('Abigahil', 'F', 1.0)
# ('Abigai', 'F', 1.0)
# ('Abigail', 'F', 0.9981794266240172)
# ('Abigaile', 'F', 1.0)
# ('Abigailgrace', 'F', 1.0)
# ('Abigaille', 'F', 1.0)
# ('Abigailmarie', 'F', 1.0)
# ('Abigailrose', 'F', 1.0)
# ('Abigal', 'F', 1.0)
# ('Abigale', 'F', 1.0)
# ('Abigayil', 'F', 1.0)
# ('Abigayl', 'F', 1.0)
# ('Abigayle', 'F', 0.9991298294465716)
# ('Abigeal', 'F', 1.0)
# ('Abigel', 'F', 1.0)
# ('Abigial', 'F', 1.0)
# ('Abiha', 'F', 1.0)
# ('Abihail', 'F', 1.0)
# ('Abijah', 'M', 0.8222996515679443)
# ('Abilene', 'F', 1.0)
# ('Abilgail', 'F', 1.0)
# ('Abilio', 'M', 1.0)
# ('Abilyn', 'F', 1.0)
# ('Abilynn', 'F', 1.0)
# ('Abimael', 'M', 1.0)
# ('Abimbola', 'F', 0.9411764705882352)
# ('Abimelec', 'M', 1.0)
# ('Abin', 'M', 1.0)
# ('Abinadab', 'M', 1.0)
# ('Abinadi', 'M', 1.0)
# ('Abinav', 'M', 1.0)
# ('Abinaya', 'F', 1.0)
# ('Abiodun', 'M', 1.0)
# ('Abiola', 'F', 0.7684210526315789)
# ('Abiona', 'F', 1.0)
# ('Abir', 'M', 0.7302052785923754)
# ('Abira', 'F', 1.0)
# ('Abiram', 'M', 1.0)
# ('Abirami', 'F', 1.0)
# ('Abisag', 'F', 1.0)
# ('Abisai', 'M', 0.9682539682539684)
# ('Abish', 'F', 1.0)
# ('Abisha', 'F', 1.0)
# ('Abishai', 'M', 0.8514285714285714)
# ('Abishek', 'M', 1.0)
# ('Abisola', 'F', 1.0)
# ('Abiud', 'M', 1.0)
# ('Abiyah', 'F', 0.5)
# ('Abla', 'F', 1.0)
# ('Able', 'M', 1.0)
# ('Abnel', 'M', 1.0)
# ('Abner', 'M', 1.0)
# ('Abney', 'F', 0.6666666666666666)
# ('Abony', 'F', 1.0)
# ('Abou', 'M', 1.0)
# ('Aboubacar', 'M', 1.0)
# ('Aboubakar', 'M', 1.0)
# ('Abra', 'F', 1.0)
# ('Abraam', 'M', 1.0)
# ('Abraar', 'M', 1.0)
# ('Abrah', 'F', 1.0)
# ('Abraham', 'M', 0.9975810583763302)
# ('Abrahan', 'M', 1.0)
# ('Abraheem', 'M', 1.0)
# ('Abrahem', 'M', 1.0)
# ('Abrahim', 'M', 1.0)
# ('Abrahm', 'M', 1.0)
# ('Abram', 'M', 1.0)
# ('Abran', 'M', 1.0)
# ('Abranda', 'F', 1.0)
# ('Abrar', 'F', 0.5257575757575758)
# ('Abraxas', 'M', 0.5454545454545454)
# ('Abrea', 'F', 1.0)
# ('Abreana', 'F', 1.0)
# ('Abreanna', 'F', 1.0)
# ('Abree', 'F', 1.0)
# ('Abreia', 'F', 1.0)
# ('Abren', 'M', 1.0)
# ('Abreona', 'F', 1.0)
# ('Abreonna', 'F', 1.0)
# ('Abrey', 'F', 1.0)
# ('Abreya', 'F', 1.0)
# ('Abrham', 'M', 1.0)
# ('Abri', 'F', 1.0)
# ('Abria', 'F', 1.0)
# ('Abriah', 'F', 1.0)
# ('Abrial', 'F', 1.0)
# ('Abriam', 'M', 1.0)
# ('Abrian', 'M', 0.9823943661971832)
# ('Abriana', 'F', 1.0)
# ('Abrianna', 'F', 1.0)
# ('Abriannah', 'F', 1.0)
# ('Abrianne', 'F', 1.0)
# ('Abrie', 'F', 1.0)
# ('Abriel', 'F', 0.6465422612513722)
# ('Abriela', 'F', 1.0)
# ('Abriele', 'F', 1.0)
# ('Abriella', 'F', 1.0)
# ('Abrielle', 'F', 1.0)
# ('Abrien', 'M', 1.0)
# ('Abrienne', 'F', 1.0)
# ('Abrigail', 'F', 1.0)
# ('Abrihet', 'F', 1.0)
# ('Abril', 'F', 0.9992801612438814)
# ('Abrille', 'F', 1.0)
# ('Abrina', 'F', 1.0)
# ('Abrion', 'M', 1.0)
# ('Abriona', 'F', 1.0)
# ('Abrionna', 'F', 1.0)
# ('Abrish', 'F', 1.0)
# ('Abriya', 'F', 1.0)
# ('Abriyah', 'F', 1.0)
# ('Abriyana', 'F', 1.0)
# ('Abrom', 'M', 1.0)
# ('Abron', 'M', 1.0)
# ('Abrum', 'M', 1.0)
# ('Abry', 'F', 1.0)
# ('Abryana', 'F', 1.0)
# ('Abryanna', 'F', 1.0)
# ('Abryella', 'F', 1.0)
# ('Abryelle', 'F', 1.0)
# ('Abryl', 'F', 1.0)
# ('Absalat', 'F', 1.0)
# ('Absalom', 'M', 1.0)
# ('Absalon', 'M', 1.0)
# ('Abshir', 'M', 1.0)
# ('Absidy', 'F', 1.0)
# ('Abtin', 'M', 1.0)
# ('Abu', 'M', 1.0)
# ('Abubacar', 'M', 1.0)
# ('Abubacarr', 'M', 1.0)
# ('Abubakar', 'M', 1.0)
# ('Abubakarr', 'M', 1.0)
# ('Abubakary', 'M', 1.0)
# ('Abubaker', 'M', 1.0)
# ('Abubakr', 'M', 1.0)
# ('Abuk', 'F', 1.0)
# ('Abukar', 'M', 1.0)
# ('Abundio', 'M', 1.0)
# ('Aby', 'F', 0.7777777777777778)
# ('Abyade', 'F', 1.0)
# ('Abyan', 'M', 0.7777777777777778)
# ('Abygael', 'F', 1.0)
# ('Abygail', 'F', 1.0)
# ('Abygaile', 'F', 1.0)
# ('Abygale', 'F', 1.0)
# ('Abygayle', 'F', 1.0)
# ('Abyssinia', 'F', 1.0)
# ('Ac', 'M', 1.0)
# ('Acacia', 'F', 1.0)
# ('Acacius', 'M', 1.0)
# ('Acadia', 'F', 1.0)
# ('Acamas', 'M', 1.0)
# ('Acari', 'M', 1.0)
# ('Acasia', 'F', 1.0)
# ('Accacia', 'F', 1.0)
# ('Accalia', 'F', 1.0)
# ('Access', 'M', 1.0)
# ('Accie', 'M', 1.0)
# ('Accursio', 'M', 1.0)
# ('Ace', 'M', 0.9976661175178472)
# ('Acea', 'M', 0.927536232)
# ('Acein', 'M', 1.0)
# ('Acel', 'M', 1.0)
# ('Acelin', 'M', 0.8389830508474576)
# ('Acelino', 'M', 1.0)
# ('Acelyn', 'F', 0.985632184)
# ('Acelynn', 'F', 1.0)
# ('Acen', 'M', 1.0)
# ('Acencion', 'M', 1.0)
# ('Aceon', 'M', 1.0)
# ('Acer', 'M', 1.0)
# ('Aceson', 'M', 1.0)
# ('Acesyn', 'M', 1.0)
# ('Aceton', 'M', 1.0)
# ('Acey', 'M', 0.9623529411764706)
# ('Aceyn', 'M', 1.0)
# ('Achai', 'M', 1.0)
# ('Achaia', 'F', 1.0)
# ('Achan', 'F', 1.0)
# ('Achante', 'F', 1.0)
# ('Achanti', 'F', 1.0)
# ('Achary', 'M', 1.0)
# ('Achazia', 'F', 1.0)
# ('Achel', 'F', 1.0)
# ('Acheron', 'M', 1.0)
# ('Achille', 'M', 1.0)
# ('Achilles', 'M', 1.0)
# ('Achilleus', 'M', 1.0)
# ('Achillies', 'M', 1.0)
# ('Achintya', 'M', 1.0)
# ('Achol', 'F', 1.0)
# ('Achraf', 'M', 1.0)
# ('Achsa', 'F', 1.0)
# ('Achsah', 'F', 1.0)
# ('Achyut', 'M', 1.0)
# ('Achyuth', 'M', 1.0)
# ('Acia', 'F', 1.0)
# ('Aciano', 'M', 1.0)
# ('Acie', 'M', 0.9782503624939584)
# ('Aciel', 'M', 1.0)
# ('Acil', 'M', 1.0)
# ('Acire', 'F', 1.0)
# ('Ackeem', 'M', 1.0)
# ('Ackley', 'M', 1.0)
# ('Acob', 'M', 1.0)
# ('Acquanetta', 'F', 1.0)
# ('Acquanette', 'F', 1.0)
# ('Acsa', 'F', 1.0)
# ('Acura', 'F', 1.0)
# ('Acxel', 'M', 1.0)
# ('Acy', 'M', 0.982078853)
# ('Ad', 'M', 1.0)
# ('Ada', 'F', 0.9970135736849484)
# ('Adabel', 'F', 1.0)
# ('Adabella', 'F', 1.0)
# ('Adabelle', 'F', 1.0)
# ('Adacia', 'F', 1.0)
# ('Adae', 'M', 1.0)
# ('Adael', 'M', 1.0)
# ('Adaelyn', 'F', 1.0)
# ('Adaeze', 'F', 1.0)
# ('Adagio', 'M', 1.0)
# ('Adah', 'F', 1.0)
# ('Adahir', 'M', 1.0)
# ('Adahli', 'F', 1.0)
# ('Adahlia', 'F', 1.0)
# ('Adahy', 'M', 1.0)
# ('Adai', 'F', 1.0)
# ('Adaia', 'F', 1.0)
# ('Adaiah', 'F', 0.8571428571428571)
# ('Adaija', 'F', 1.0)
# ('Adaijah', 'F', 1.0)
# ('Adailyn', 'F', 1.0)
# ('Adain', 'M', 1.0)
# ('Adair', 'M', 0.5304381543233812)
# ('Adaira', 'F', 1.0)
# ('Adaire', 'F', 1.0)
# ('Adairis', 'F', 1.0)
# ('Adaisha', 'F', 1.0)
# ('Adaisia', 'F', 1.0)
# ('Adaja', 'F', 1.0)
# ('Adajah', 'F', 1.0)
# ('Adaku', 'F', 1.0)
# ('Adal', 'M', 1.0)
# ('Adala', 'F', 1.0)
# ('Adalade', 'F', 1.0)
# ('Adalae', 'F', 1.0)
# ('Adalai', 'F', 1.0)
# ('Adalaide', 'F', 1.0)
# ('Adalay', 'F', 1.0)
# ('Adalaya', 'F', 1.0)
# ('Adalayde', 'F', 1.0)
# ('Adalbert', 'M', 1.0)
# ('Adalberto', 'M', 1.0)
# ('Adale', 'F', 1.0)
# ('Adalea', 'F', 1.0)
# ('Adaleah', 'F', 1.0)
# ('Adalee', 'F', 1.0)
# ('Adaleen', 'F', 1.0)
# ('Adaleena', 'F', 1.0)
# ('Adalei', 'F', 1.0)
# ('Adaleia', 'F', 1.0)
# ('Adaleigh', 'F', 1.0)
# ('Adaleine', 'F', 1.0)
# ('Adalen', 'F', 1.0)
# ('Adalena', 'F', 1.0)
# ('Adalene', 'F', 1.0)
# ('Adaley', 'F', 1.0)
# ('Adaleya', 'F', 1.0)
# ('Adaleyza', 'F', 1.0)
# ('Adalhi', 'F', 1.0)
# ('Adali', 'F', 0.9390862944162436)
# ('Adalia', 'F', 1.0)
# ('Adaliah', 'F', 1.0)
# ('Adalicia', 'F', 1.0)
# ('Adalid', 'M', 0.9)
# ('Adalida', 'F', 1.0)
# ('Adalie', 'F', 1.0)
# ('Adaliene', 'F', 1.0)
# ('Adalin', 'F', 1.0)
# ('Adalina', 'F', 1.0)
# ('Adalind', 'F', 1.0)
# ('Adalinda', 'F', 1.0)
# ('Adaline', 'F', 1.0)
# ('Adalinn', 'F', 1.0)
# ('Adalinne', 'F', 1.0)
# ('Adalis', 'F', 1.0)
# ('Adalisa', 'F', 1.0)
# ('Adalise', 'F', 1.0)
# ('Adalisse', 'F', 1.0)
# ('Adalius', 'M', 1.0)
# ('Adaliyah', 'F', 1.0)
# ('Adaliz', 'F', 1.0)
# ('Adalize', 'F', 1.0)
# ('Adallyn', 'F', 1.0)
# ('Adaly', 'F', 1.0)
# ('Adalya', 'F', 1.0)
# ('Adalye', 'F', 1.0)
# ('Adalyn', 'F', 1.0)
# ('Adalyna', 'F', 1.0)
# ('Adalynd', 'F', 1.0)
# ('Adalyne', 'F', 1.0)
# ('Adalynn', 'F', 1.0)
# ('Adalynne', 'F', 1.0)
# ('Adalys', 'F', 1.0)
# ('Adalyse', 'F', 1.0)
# ('Adam', 'M', 0.9962667415041596)
# ('Adama', 'F', 0.5975935828877005)
# ('Adamae', 'F', 1.0)
# ('Adamari', 'F', 1.0)
# ('Adamarie', 'F', 1.0)
# ('Adamaris', 'F', 1.0)
# ('Adamariz', 'F', 1.0)
# ('Adamary', 'F', 1.0)
# ('Adamarys', 'F', 1.0)
# ('Adamina', 'F', 1.0)
# ('Adamm', 'M', 1.0)
# ('Adamma', 'F', 1.0)
# ('Adammichael', 'M', 1.0)
# ('Adamo', 'M', 1.0)
# ('Adams', 'M', 1.0)
# ('Adan', 'M', 0.996122935261096)
# ('Adana', 'F', 1.0)
# ('Adaneli', 'F', 1.0)
# ('Adanelly', 'F', 1.0)
# ('Adanely', 'F', 1.0)
# ('Adanna', 'F', 1.0)
# ('Adannaya', 'F', 1.0)
# ('Adante', 'M', 1.0)
# ('Adanya', 'F', 1.0)
# ('Adaobi', 'F', 1.0)
# ('Adaora', 'F', 1.0)
# ('Adar', 'M', 0.6666666666666666)
# ('Adara', 'F', 1.0)
# ('Adarah', 'F', 1.0)
# ('Adari', 'M', 1.0)
# ('Adaria', 'F', 1.0)
# ('Adarian', 'M', 1.0)
# ('Adarien', 'M', 1.0)
# ('Adarion', 'M', 1.0)
# ('Adarious', 'M', 1.0)
# ('Adarius', 'M', 1.0)
# ('Adarrius', 'M', 1.0)
# ('Adarryl', 'M', 1.0)
# ('Adarryll', 'M', 1.0)
# ('Adarsh', 'M', 1.0)
# ('Adaryl', 'M', 1.0)
# ('Adaryll', 'M', 1.0)
# ('Adasha', 'F', 1.0)
# ('Adashia', 'F', 1.0)
# ('Adasia', 'F', 1.0)
# ('Adason', 'F', 0.5)
# ('Adassa', 'F', 1.0)
# ('Adasyn', 'F', 1.0)
# ('Adaugo', 'F', 1.0)
# ('Adaure', 'F', 1.0)
# ('Adavia', 'F', 1.0)
# ('Adavion', 'M', 1.0)
# ('Adaya', 'F', 1.0)
# ('Adayah', 'F', 1.0)
# ('Adayla', 'F', 1.0)
# ('Adaysha', 'F', 1.0)
# ('Adayshia', 'F', 1.0)
# ('Adaysia', 'F', 1.0)
# ('Adbeel', 'M', 1.0)
# ('Adbiel', 'M', 1.0)
# ('Add', 'M', 1.0)
# ('Adda', 'F', 1.0)
# ('Addah', 'F', 1.0)
# ('Addai', 'M', 1.0)
# ('Addalee', 'F', 1.0)
# ('Addaleigh', 'F', 1.0)
# ('Addaley', 'F', 1.0)
# ('Addalie', 'F', 1.0)
# ('Addalin', 'F', 1.0)
# ('Addalina', 'F', 1.0)
# ('Addaline', 'F', 1.0)
# ('Addalyn', 'F', 1.0)
# ('Addalyne', 'F', 1.0)
# ('Addalynn', 'F', 1.0)
# ('Addalynne', 'F', 1.0)
# ('Addam', 'M', 1.0)
# ('Addan', 'M', 1.0)
# ('Addasyn', 'F', 1.0)
# ('Addelin', 'F', 1.0)
# ('Addelina', 'F', 1.0)
# ('Addeline', 'F', 1.0)
# ('Addell', 'F', 1.0)
# ('Addelyn', 'F', 1.0)
# ('Addelyne', 'F', 1.0)
# ('Addelynn', 'F', 1.0)
# ('Addelynne', 'F', 1.0)
# ('Adden', 'M', 1.0)
# ('Adderly', 'M', 1.0)
# ('Addeson', 'F', 1.0)
# ('Addesyn', 'F', 1.0)
# ('Addey', 'F', 1.0)
# ('Addi', 'F', 1.0)
# ('Addia', 'F', 1.0)
# ('Addicus', 'M', 1.0)
# ('Addicyn', 'F', 1.0)
# ('Addie', 'F', 0.9837677751904688)
# ('Addiel', 'M', 1.0)
# ('Addielynn', 'F', 1.0)
# ('Addiemae', 'F', 1.0)
# ('Addieson', 'F', 1.0)
# ('Addilee', 'F', 1.0)
# ('Addileigh', 'F', 1.0)
# ('Addiley', 'F', 1.0)
# ('Addiline', 'F', 1.0)
# ('Addilyn', 'F', 1.0)
# ('Addilyne', 'F', 1.0)
# ('Addilynn', 'F', 1.0)
# ('Addilynne', 'F', 1.0)
# ('Addine', 'F', 1.0)
# ('Addington', 'M', 0.6153846153846154)
# ('Addis', 'M', 0.7140077821011673)
# ('Addisan', 'F', 1.0)
# ('Addisen', 'F', 0.9942196531791908)
# ('Addisin', 'F', 1.0)
# ('Addison', 'F', 0.893145213)
# ('Addisson', 'F', 1.0)
# ('Addiston', 'F', 1.0)
# ('Addisun', 'F', 1.0)
# ('Addisyn', 'F', 1.0)
# ('Addisynn', 'F', 1.0)
# ('Addix', 'M', 1.0)
# ('Addle', 'F', 1.0)
# ('Addlee', 'F', 1.0)
# ('Addley', 'F', 1.0)
# ('Addlie', 'F', 1.0)
# ('Addlyn', 'F', 1.0)
# ('Addlynn', 'F', 1.0)
# ('Addonis', 'M', 1.0)
# ('Addriana', 'F', 1.0)
# ('Addrianna', 'F', 1.0)
# ('Addrienne', 'F', 1.0)
# ('Addsion', 'F', 1.0)
# ('Addy', 'F', 0.9797421731123388)
# ('Addylan', 'F', 1.0)
# ('Addylen', 'F', 1.0)
# ('Addylin', 'F', 1.0)
# ('Addyline', 'F', 1.0)
# ('Addylyn', 'F', 1.0)
# ('Addylynn', 'F', 1.0)
# ('Addysan', 'F', 1.0)
# ('Addysen', 'F', 1.0)
# ('Addysin', 'F', 1.0)
# ('Addysn', 'F', 1.0)
# ('Addyson', 'F', 0.9975455559687616)
# ('Addysun', 'F', 1.0)
# ('Addysyn', 'F', 1.0)
# ('Ade', 'M', 0.9806949806949808)
# ('Adea', 'F', 1.0)
# ('Adean', 'F', 0.8017241379310345)
# ('Adeana', 'F', 1.0)
# ('Adeanna', 'F', 1.0)
# ('Adebayo', 'M', 1.0)
# ('Adebisi', 'F', 1.0)
# ('Adebola', 'F', 0.7777777777777778)
# ('Adebowale', 'M', 1.0)
# ('Adecyn', 'F', 1.0)
# ('Adedamola', 'M', 1.0)
# ('Adedayo', 'M', 1.0)
# ('Adedeji', 'M', 1.0)
# ('Adedotun', 'M', 1.0)
# ('Adedoyin', 'F', 1.0)
# ('Adee', 'F', 1.0)
# ('Adeeb', 'M', 1.0)
# ('Adeeba', 'F', 1.0)
# ('Adeel', 'M', 1.0)
# ('Adeem', 'M', 1.0)
# ('Adeen', 'M', 1.0)
# ('Adeena', 'F', 1.0)
# ('Adein', 'M', 1.0)
# ('Adeja', 'F', 1.0)
# ('Adejah', 'F', 1.0)
# ('Adekemi', 'F', 1.0)
# ('Adekunle', 'M', 1.0)
# ('Adel', 'F', 0.5268993839835729)
# ('Adela', 'F', 1.0)
# ('Adelade', 'F', 1.0)
# ('Adelae', 'F', 1.0)
# ('Adelah', 'F', 1.0)
# ('Adelai', 'F', 1.0)
# ('Adelaid', 'F', 1.0)
# ('Adelaida', 'F', 1.0)
# ('Adelaide', 'F', 1.0)
# ('Adelaido', 'M', 1.0)
# ('Adelaina', 'F', 1.0)
# ('Adelaine', 'F', 1.0)
# ('Adelais', 'F', 1.0)
# ('Adelane', 'F', 1.0)
# ('Adelard', 'M', 1.0)
# ('Adelay', 'F', 1.0)
# ('Adelaya', 'F', 1.0)
# ('Adelayda', 'F', 1.0)
# ('Adelayde', 'F', 1.0)
# ('Adelayne', 'F', 1.0)
# ('Adelbert', 'M', 1.0)
# ('Adele', 'F', 0.9997166044055134)
# ('Adelean', 'F', 1.0)
# ('Adelee', 'F', 1.0)
# ('Adeleen', 'F', 1.0)
# ('Adelei', 'F', 1.0)
# ('Adeleigh', 'F', 1.0)
# ('Adeleine', 'F', 1.0)
# ('Adeleke', 'M', 1.0)
# ('Adelen', 'F', 1.0)
# ('Adelena', 'F', 1.0)
# ('Adelene', 'F', 1.0)
# ('Adeley', 'F', 1.0)
# ('Adelfa', 'F', 1.0)
# ('Adelfina', 'F', 1.0)
# ('Adelfo', 'M', 1.0)
# ('Adelheid', 'F', 1.0)
# ('Adeli', 'F', 1.0)
# ('Adelia', 'F', 1.0)
# ('Adeliah', 'F', 1.0)
# ('Adelice', 'F', 1.0)
# ('Adelicia', 'F', 1.0)
# ('Adelie', 'F', 1.0)
# ('Adelilah', 'F', 1.0)
# ('Adelin', 'F', 1.0)
# ('Adelina', 'F', 1.0)
# ('Adelinah', 'F', 1.0)
# ('Adelind', 'F', 1.0)
# ('Adeline', 'F', 0.9995758938038084)
# ('Adelinn', 'F', 1.0)
# ('Adelinne', 'F', 1.0)
# ('Adelino', 'M', 1.0)
# ('Adelis', 'F', 1.0)
# ('Adelisa', 'F', 1.0)
# ('Adelise', 'F', 1.0)
# ('Adelita', 'F', 1.0)
# ('Adeliz', 'F', 1.0)
# ('Adell', 'F', 0.8540420203144566)
# ('Adella', 'F', 1.0)
# ('Adelle', 'F', 1.0)
# ('Adellia', 'F', 1.0)
# ('Adelline', 'F', 1.0)
# ('Adellyn', 'F', 1.0)
# ('Adellynn', 'F', 1.0)
# ('Adelma', 'F', 1.0)
# ('Adelmira', 'F', 1.0)
# ('Adelmo', 'M', 1.0)
# ('Adelore', 'M', 1.0)
# ('Adelphia', 'F', 1.0)
# ('Adely', 'F', 1.0)
# ('Adelya', 'F', 1.0)
# ('Adelyn', 'F', 0.9994697773064688)
# ('Adelyna', 'F', 1.0)
# ('Adelyne', 'F', 1.0)
# ('Adelynn', 'F', 1.0)
# ('Adelynne', 'F', 1.0)
# ('Adelys', 'F', 1.0)
# ('Adem', 'M', 1.0)
# ('Ademar', 'M', 1.0)
# ('Ademide', 'M', 0.8484848484848485)
# ('Ademir', 'M', 1.0)
# ('Ademola', 'M', 1.0)
# ('Aden', 'M', 0.9709977436574762)
# ('Adena', 'F', 1.0)
# ('Adene', 'F', 1.0)
# ('Adenike', 'F', 1.0)
# ('Adeniyi', 'M', 1.0)
# ('Adenn', 'M', 1.0)
# ('Adeola', 'F', 0.9327731092436976)
# ('Adeolu', 'M', 1.0)
# ('Adeoluwa', 'M', 1.0)
# ('Adeon', 'M', 1.0)
# ('Ader', 'F', 1.0)
# ('Adera', 'F', 1.0)
# ('Aderemi', 'M', 1.0)
# ('Aderinsola', 'F', 1.0)
# ('Adero', 'F', 1.0)
# ('Aderonke', 'F', 1.0)
# ('Aderyn', 'F', 1.0)
# ('Adesewa', 'F', 1.0)
# ('Adesh', 'M', 1.0)
# ('Adesha', 'F', 1.0)
# ('Adesina', 'F', 1.0)
# ('Adesire', 'F', 1.0)
# ('Adesola', 'F', 1.0)
# ('Adessa', 'F', 1.0)
# ('Adesuwa', 'F', 1.0)
# ('Adetayo', 'M', 1.0)
# ('Adetokunbo', 'M', 0.9438202247191012)
# ('Adetola', 'M', 1.0)
# ('Adeva', 'F', 1.0)
# ('Adewale', 'M', 1.0)
# ('Adey', 'F', 1.0)
# ('Adeyemi', 'M', 1.0)
# ('Adeyinka', 'F', 0.5)
# ('Adger', 'M', 1.0)
# ('Adgie', 'F', 0.5833333333333334)
# ('Adham', 'M', 1.0)
# ('Adhara', 'F', 1.0)
# ('Adharsh', 'M', 1.0)
# ('Adhav', 'M', 1.0)
# ('Adheesh', 'M', 1.0)
# ('Adhem', 'M', 1.0)
# ('Adhemar', 'M', 1.0)
# ('Adhira', 'F', 1.0)
# ('Adhiraj', 'M', 1.0)
# ('Adhithi', 'F', 1.0)
# ('Adhithya', 'M', 1.0)
# ('Adhitya', 'M', 1.0)
# ('Adhley', 'F', 1.0)
# ('Adhrit', 'M', 1.0)
# ('Adhrith', 'M', 1.0)
# ('Adhvaith', 'M', 1.0)
# ('Adhvik', 'M', 1.0)
# ('Adhvika', 'F', 1.0)
# ('Adhya', 'F', 1.0)
# ('Adhyan', 'M', 1.0)
# ('Adi', 'F', 0.5827868852459016)
# ('Adia', 'F', 1.0)
# ('Adiah', 'F', 1.0)
# ('Adiam', 'F', 1.0)
# ('Adian', 'M', 1.0)
# ('Adiana', 'F', 1.0)
# ('Adianez', 'F', 1.0)
# ('Adianna', 'F', 1.0)
# ('Adib', 'M', 1.0)
# ('Adiba', 'F', 1.0)
# ('Adidas', 'M', 1.0)
# ('Adie', 'F', 0.9069767441860463)
# ('Adiel', 'M', 0.9370477568740956)
# ('Adiela', 'F', 1.0)
# ('Adiella', 'F', 1.0)
# ('Adielle', 'F', 1.0)
# ('Adien', 'M', 1.0)
# ('Adijah', 'F', 1.0)
# ('Adika', 'M', 1.0)
# ('Adikus', 'M', 1.0)
# ('Adil', 'M', 1.0)
# ('Adila', 'F', 1.0)
# ('Adilah', 'F', 1.0)
# ('Adilee', 'F', 1.0)
# ('Adileigh', 'F', 1.0)
# ('Adilen', 'F', 1.0)
# ('Adilena', 'F', 1.0)
# ('Adilene', 'F', 0.9985754985754984)
# ('Adileni', 'F', 1.0)
# ('Adilenne', 'F', 1.0)
# ('Adileny', 'F', 1.0)
# ('Adiley', 'F', 1.0)
# ('Adilia', 'F', 1.0)
# ('Adiline', 'F', 1.0)
# ('Adilson', 'M', 1.0)
# ('Adilyn', 'F', 1.0)
# ('Adilyne', 'F', 1.0)
# ('Adilynn', 'F', 1.0)
# ('Adilynne', 'F', 1.0)
# ('Adin', 'M', 0.9678984695782008)
# ('Adina', 'F', 1.0)
# ('Adinah', 'F', 1.0)
# ('Adine', 'F', 1.0)
# ('Adir', 'M', 1.0)
# ('Adira', 'F', 1.0)
# ('Adirah', 'F', 1.0)
# ('Adis', 'M', 0.9473684210526316)
# ('Adisa', 'F', 0.5816993464052288)
# ('Adisen', 'F', 1.0)
# ('Adison', 'F', 0.8248603351955307)
# ('Adisson', 'F', 0.9418604651162792)
# ('Adisyn', 'F', 1.0)
# ('Adisynn', 'F', 1.0)
# ('Adisynne', 'F', 1.0)
# ('Adit', 'M', 1.0)
# ('Adith', 'M', 1.0)
# ('Adithi', 'F', 1.0)
# ('Adithri', 'F', 1.0)
# ('Adithya', 'M', 1.0)
# ('Aditi', 'F', 1.0)
# ('Aditri', 'F', 1.0)
# ('Aditya', 'M', 0.998855049)
# ('Adiv', 'M', 1.0)
# ('Adiva', 'F', 1.0)
# ('Adiya', 'F', 1.0)
# ('Adiyah', 'F', 1.0)
# ('Adiyan', 'M', 1.0)
# ('Adja', 'F', 1.0)
# ('Adji', 'F', 1.0)
# ('Adjoa', 'F', 1.0)
# ('Adjua', 'F', 1.0)
# ('Adlai', 'M', 0.9065420560747663)
# ('Adlan', 'M', 1.0)
# ('Adlar', 'M', 1.0)
# ('Adlea', 'F', 1.0)
# ('Adlean', 'F', 1.0)
# ('Adlee', 'F', 1.0)
# ('Adlei', 'F', 1.0)
# ('Adleigh', 'F', 1.0)
# ('Adlemi', 'F', 1.0)
# ('Adlen', 'F', 1.0)
# ('Adlena', 'F', 1.0)
# ('Adlene', 'F', 1.0)
# ('Adler', 'M', 0.9090909090909092)
# ('Adley', 'F', 0.8263274336283186)
# ('Adlia', 'M', 1.0)
# ('Adlie', 'F', 1.0)
# ('Adlih', 'F', 1.0)
# ('Adlin', 'F', 1.0)
# ('Adlina', 'F', 1.0)
# ('Adline', 'F', 1.0)
# ('Adly', 'F', 1.0)
# ('Adlyn', 'F', 1.0)
# ('Adlynn', 'F', 1.0)
# ('Adma', 'M', 1.0)
# ('Admir', 'M', 1.0)
# ('Admiral', 'M', 1.0)
# ('Admire', 'F', 0.9107142857142856)
# ('Adn', 'F', 1.0)
# ('Adna', 'F', 0.9696202531645568)
# ('Adnaan', 'M', 1.0)
# ('Adnan', 'M', 1.0)
# ('Adnel', 'M', 1.0)
# ('Adner', 'M', 1.0)
# ('Adniel', 'M', 1.0)
# ('Adnrea', 'F', 1.0)
# ('Adnrew', 'M', 1.0)
# ('Ado', 'M', 1.0)
# ('Adolf', 'M', 1.0)
# ('Adolfo', 'M', 0.9993414553836022)
# ('Adoline', 'F', 1.0)
# ('Adolph', 'M', 0.99893185216834)
# ('Adolpha', 'F', 1.0)
# ('Adolphe', 'M', 1.0)
# ('Adolphine', 'F', 1.0)
# ('Adolpho', 'M', 1.0)
# ('Adolphus', 'M', 1.0)
# ('Adom', 'M', 1.0)
# ('Adomas', 'M', 1.0)
# ('Adon', 'M', 1.0)
# ('Adona', 'F', 1.0)
# ('Adonai', 'M', 0.7829232995658466)
# ('Adonay', 'M', 1.0)
# ('Adoncia', 'F', 1.0)
# ('Adones', 'M', 1.0)
# ('Adoni', 'M', 1.0)
# ('Adonia', 'F', 1.0)
# ('Adoniah', 'M', 0.6818181818181818)
# ('Adonias', 'M', 1.0)
# ('Adonica', 'F', 1.0)
# ('Adonijah', 'M', 0.9301075268817204)
# ('Adoniram', 'M', 1.0)
# ('Adonis', 'M', 0.9902459129001236)
# ('Adoniz', 'M', 1.0)
# ('Adonna', 'F', 1.0)
# ('Adonnis', 'M', 1.0)
# ('Adontae', 'M', 1.0)
# ('Adonte', 'M', 1.0)
# ('Adonus', 'M', 1.0)
# ('Adony', 'M', 1.0)
# ('Adonya', 'F', 1.0)
# ('Adonys', 'M', 1.0)
# ('Adora', 'F', 1.0)
# ('Adorabella', 'F', 1.0)
# ('Adorable', 'F', 1.0)
# ('Adorae', 'F', 1.0)
# ('Adorah', 'F', 1.0)
# ('Adoraim', 'M', 1.0)
# ('Adore', 'F', 0.9297297297297298)
# ('Adoree', 'F', 1.0)
# ('Adoria', 'F', 1.0)
# ('Adorian', 'M', 1.0)
# ('Adorion', 'M', 1.0)
# ('Adorn', 'F', 1.0)
# ('Adra', 'F', 1.0)
# ('Adrain', 'M', 0.8786003840409644)
# ('Adraine', 'F', 0.9779735682819384)
# ('Adrainne', 'F', 1.0)
# ('Adran', 'M', 1.0)
# ('Adraya', 'F', 1.0)
# ('Adre', 'M', 1.0)
# ('Adrea', 'F', 1.0)
# ('Adream', 'F', 1.0)
# ('Adrean', 'M', 0.6371681415929203)
# ('Adreana', 'F', 1.0)
# ('Adreann', 'F', 1.0)
# ('Adreanna', 'F', 1.0)
# ('Adreanne', 'F', 1.0)
# ('Adreauna', 'F', 1.0)
# ('Adree', 'F', 1.0)
# ('Adreena', 'F', 1.0)
# ('Adreian', 'M', 1.0)
# ('Adrein', 'M', 1.0)
# ('Adreina', 'F', 1.0)
# ('Adreinne', 'F', 1.0)
# ('Adrell', 'M', 1.0)
# ('Adren', 'M', 1.0)
# ('Adrena', 'F', 1.0)
# ('Adrene', 'F', 1.0)
# ('Adreon', 'M', 1.0)
# ('Adreona', 'F', 1.0)
# ('Adreonna', 'F', 1.0)
# ('Adrew', 'M', 1.0)
# ('Adrey', 'F', 1.0)
# ('Adreyan', 'M', 1.0)
# ('Adreyona', 'F', 1.0)
# ('Adri', 'F', 0.888268156)
# ('Adria', 'F', 0.9988097262370346)
# ('Adriaan', 'M', 1.0)
# ('Adriah', 'F', 1.0)
# ('Adriahna', 'F', 1.0)
# ('Adrial', 'M', 1.0)
# ('Adrialis', 'F', 1.0)
# ('Adrialys', 'F', 1.0)
# ('Adriam', 'M', 1.0)
# ('Adrian', 'M', 0.9359514572253196)
# ('Adriana', 'F', 0.995324365)
# ('Adrianah', 'F', 1.0)
# ('Adriane', 'F', 0.9567618747041188)
# ('Adrianjames', 'M', 1.0)
# ('Adriann', 'F', 0.8987341772151899)
# ('Adrianna', 'F', 0.999577563952124)
# ('Adriannah', 'F', 1.0)
# ('Adrianne', 'F', 0.997615018)
# ('Adrianno', 'M', 1.0)
# ('Adrianny', 'F', 1.0)
# ('Adriano', 'M', 1.0)
# ('Adrianpaul', 'M', 1.0)
# ('Adriauna', 'F', 1.0)
# ('Adriaunna', 'F', 1.0)
# ('Adric', 'M', 1.0)
# ('Adrick', 'M', 1.0)
# ('Adrie', 'F', 1.0)
# ('Adriean', 'M', 1.0)
# ('Adrieana', 'F', 1.0)
# ('Adrieanna', 'F', 1.0)
# ('Adrieanne', 'F', 1.0)
# ('Adriel', 'M', 0.923973481608212)
# ('Adriela', 'F', 1.0)
# ('Adriell', 'M', 1.0)
# ('Adriella', 'F', 1.0)
# ('Adrielle', 'F', 1.0)
# ('Adrien', 'M', 0.8488684741205467)
# ('Adriena', 'F', 1.0)
# ('Adriene', 'F', 0.974720265230004)
# ('Adrienn', 'F', 0.7941176470588235)
# ('Adrienna', 'F', 1.0)
# ('Adrienne', 'F', 0.9943574233738094)
# ('Adriennie', 'F', 1.0)
# ('Adrieonna', 'F', 1.0)
# ('Adrihana', 'F', 1.0)
# ('Adrihanna', 'F', 1.0)
# ('Adrija', 'F', 1.0)
# ('Adrijana', 'F', 1.0)
# ('Adrik', 'M', 1.0)
# ('Adrika', 'F', 1.0)
# ('Adrin', 'M', 0.9658119658119658)
# ('Adrina', 'F', 1.0)
# ('Adrine', 'F', 0.927536232)
# ('Adrinna', 'F', 1.0)
# ('Adrinne', 'F', 1.0)
# ('Adrion', 'M', 1.0)
# ('Adriona', 'F', 1.0)
# ('Adrionna', 'F', 1.0)
# ('Adris', 'M', 1.0)
# ('Adrita', 'F', 1.0)
# ('Adrith', 'M', 1.0)
# ('Adriunna', 'F', 1.0)
# ('Adrius', 'M', 1.0)
# ('Adriyan', 'M', 1.0)
# ('Adriyana', 'F', 1.0)
# ('Adriyanna', 'F', 1.0)
# ('Adriyel', 'M', 1.0)
# ('Adron', 'M', 1.0)
# ('Adry', 'F', 1.0)
# ('Adryan', 'M', 0.8547085201793722)
# ('Adryana', 'F', 1.0)
# ('Adryanah', 'F', 1.0)
# ('Adryann', 'F', 1.0)
# ('Adryanna', 'F', 1.0)
# ('Adryauna', 'F', 1.0)
# ('Adryel', 'M', 1.0)
# ('Adryen', 'M', 1.0)
# ('Adryian', 'M', 1.0)
# ('Adryn', 'M', 0.8125)
# ('Adryon', 'M', 1.0)
# ('Adryonna', 'F', 1.0)
# ('Adulfo', 'M', 1.0)
# ('Adut', 'F', 1.0)
# ('Advait', 'M', 1.0)
# ('Advaita', 'F', 1.0)
# ('Advaith', 'M', 1.0)
# ('Advay', 'M', 1.0)
# ('Advik', 'M', 1.0)
# ('Advika', 'F', 1.0)
# ('Advit', 'M', 1.0)
# ('Advita', 'F', 1.0)
# ('Advith', 'M', 1.0)
# ('Advitha', 'F', 1.0)
# ('Adwaith', 'M', 1.0)
# ('Adwin', 'M', 1.0)
# ('Adwita', 'F', 1.0)
# ('Adwitiya', 'F', 1.0)
# ('Adwoa', 'F', 1.0)
# ('Ady', 'F', 1.0)
# ('Adya', 'F', 1.0)
# ('Adyaan', 'M', 1.0)
# ('Adyan', 'M', 1.0)
# ('Adyanna', 'F', 1.0)
# ('Adyant', 'M', 1.0)
# ('Adyen', 'M', 1.0)
# ('Adylan', 'F', 1.0)
# ('Adylee', 'F', 1.0)
# ('Adyleigh', 'F', 1.0)
# ('Adylen', 'F', 1.0)
# ('Adylene', 'F', 1.0)
# ('Adylenne', 'F', 1.0)
# ('Adylin', 'F', 1.0)
# ('Adylina', 'F', 1.0)
# ('Adyline', 'F', 1.0)
# ('Adylinn', 'F', 1.0)
# ('Adylyn', 'F', 1.0)
# ('Adylynn', 'F', 1.0)
# ('Adym', 'M', 1.0)
# ('Adyn', 'M', 0.9102362204724408)
# ('Adynn', 'M', 0.7875)
# ('Adysan', 'F', 1.0)
# ('Adysen', 'F', 1.0)
# ('Adysin', 'F', 1.0)
# ('Adyson', 'F', 0.9908577574616833)
# ('Adysson', 'F', 1.0)
# ('Adysun', 'F', 1.0)
# ('Adysyn', 'F', 1.0)
# ('Aedan', 'M', 0.9860661049902788)
# ('Aeddon', 'M', 1.0)
# ('Aeden', 'M', 0.9924487594390508)
# ('Aedin', 'M', 1.0)
# ('Aedon', 'M', 1.0)
# ('Aedric', 'M', 1.0)
# ('Aedyn', 'M', 0.8761552680221811)
# ('Aeiden', 'M', 1.0)
# ('Aeisha', 'F', 1.0)
# ('Aeja', 'F', 1.0)
# ('Aela', 'F', 1.0)
# ('Aelan', 'F', 1.0)
# ('Aelani', 'F', 1.0)
# ('Aeleen', 'F', 1.0)
# ('Aeliana', 'F', 1.0)
# ('Aelicia', 'F', 1.0)
# ('Aelisa', 'F', 1.0)
# ('Aelish', 'F', 1.0)
# ('Aelita', 'F', 1.0)
# ('Aella', 'F', 1.0)
# ('Aelred', 'M', 1.0)
# ('Aelyn', 'F', 1.0)
# ('Aelynn', 'F', 1.0)
# ('Aemelia', 'F', 1.0)
# ('Aemilia', 'F', 1.0)
# ('Aemon', 'M', 1.0)
# ('Aenea', 'F', 1.0)
# ('Aeneas', 'M', 1.0)
# ('Aengus', 'M', 1.0)
# ('Aeon', 'M', 0.5112781954887218)
# ('Aeona', 'F', 1.0)
# ('Aeowyn', 'F', 1.0)
# ('Aerabella', 'F', 1.0)
# ('Aeralyn', 'F', 1.0)
# ('Aeralynn', 'F', 1.0)
# ('Aeri', 'F', 1.0)
# ('Aerial', 'F', 0.9967567567567568)
# ('Aerian', 'M', 1.0)
# ('Aeriana', 'F', 1.0)
# ('Aerianna', 'F', 1.0)
# ('Aeric', 'M', 1.0)
# ('Aerica', 'F', 1.0)
# ('Aerick', 'M', 1.0)
# ('Aericka', 'F', 1.0)
# ('Aerie', 'F', 1.0)
# ('Aeriel', 'F', 1.0)
# ('Aeriell', 'F', 1.0)
# ('Aeriella', 'F', 1.0)
# ('Aerielle', 'F', 1.0)
# ('Aeries', 'F', 1.0)
# ('Aerik', 'M', 1.0)
# ('Aerika', 'F', 1.0)
# ('Aerilyn', 'F', 1.0)
# ('Aerilynn', 'F', 1.0)
# ('Aerin', 'F', 0.9776223776223776)
# ('Aerion', 'M', 0.8153846153846154)
# ('Aeriona', 'F', 1.0)
# ('Aerionna', 'F', 1.0)
# ('Aeris', 'F', 1.0)
# ('Aerith', 'F', 1.0)
# ('Aerius', 'M', 1.0)
# ('Aero', 'M', 0.8227848101265823)
# ('Aeron', 'M', 0.8979591836734694)
# ('Aerowyn', 'F', 1.0)
# ('Aeryal', 'F', 1.0)
# ('Aeryana', 'F', 1.0)
# ('Aeryanna', 'F', 1.0)
# ('Aeryk', 'M', 1.0)
# ('Aeryn', 'F', 0.9737704918032788)
# ('Aeryona', 'F', 1.0)
# ('Aesa', 'F', 1.0)
# ('Aesha', 'F', 1.0)
# ('Aeshia', 'F', 1.0)
# ('Aeson', 'M', 1.0)
# ('Aesop', 'M', 1.0)
# ('Aethan', 'M', 1.0)
# ('Aetna', 'F', 1.0)
# ('Aeva', 'F', 1.0)
# ('Aevah', 'F', 1.0)
# ('Aevin', 'M', 1.0)
# ('Aevry', 'F', 1.0)
# ('Aevyn', 'F', 1.0)
# ('Aeyden', 'M', 1.0)
# ('Aeyla', 'F', 1.0)
# ('Afa', 'M', 1.0)
# ('Afaf', 'F', 1.0)
# ('Afeef', 'M', 1.0)
# ('Afeni', 'F', 1.0)
# ('Aferdita', 'F', 1.0)
# ('Affaan', 'M', 1.0)
# ('Affan', 'M', 1.0)
# ('Affie', 'F', 1.0)
# ('Affinity', 'F', 1.0)
# ('Afi', 'F', 1.0)
# ('Afia', 'F', 1.0)
# ('Afif', 'M', 1.0)
# ('Afifa', 'F', 1.0)
# ('Afifah', 'F', 1.0)
# ('Afina', 'F', 1.0)
# ('Afiya', 'F', 1.0)
# ('Afiyah', 'F', 1.0)
# ('Afnan', 'F', 0.8266033254156769)
# ('Afolabi', 'M', 1.0)
# ('Afomia', 'F', 1.0)
# ('Afonso', 'M', 1.0)
# ('Afra', 'F', 1.0)
# ('Afrah', 'F', 1.0)
# ('Afraz', 'M', 1.0)
# ('Afred', 'M', 1.0)
# ('Afreen', 'F', 1.0)
# ('Africa', 'F', 1.0)
# ('Africia', 'F', 1.0)
# ('Afrika', 'F', 1.0)
# ('Afrim', 'M', 1.0)
# ('Afrin', 'F', 1.0)
# ('Afrodita', 'F', 1.0)
# ('Afsa', 'F', 1.0)
# ('Afsana', 'F', 1.0)
# ('Afsaneh', 'F', 1.0)
# ('Afshan', 'F', 1.0)
# ('Afsheen', 'F', 0.8571428571428571)
# ('Afshin', 'M', 1.0)
# ('Aftab', 'M', 1.0)
# ('Aftan', 'F', 1.0)
# ('Aften', 'F', 1.0)
# ('Aftin', 'F', 1.0)
# ('Afton', 'F', 0.862278866)
# ('Aftyn', 'F', 1.0)
# ('Afua', 'F', 1.0)
# ('Afzal', 'M', 1.0)
# ('Agam', 'M', 0.6018957345971564)
# ('Agamjot', 'M', 1.0)
# ('Agamveer', 'M', 1.0)
# ('Agape', 'F', 0.7692307692307693)
# ('Agapita', 'F', 1.0)
# ('Agapito', 'M', 1.0)
# ('Agassi', 'M', 1.0)
# ('Agasthya', 'M', 1.0)
# ('Agastya', 'M', 1.0)
# ('Agata', 'F', 1.0)
# ('Agatha', 'F', 1.0)
# ('Agathe', 'F', 1.0)
# ('Agda', 'F', 1.0)
# ('Agee', 'M', 1.0)
# ('Agel', 'M', 1.0)
# ('Agela', 'F', 1.0)
# ('Ageliki', 'F', 1.0)
# ('Agena', 'F', 1.0)
# ('Agent', 'M', 1.0)
# ('Aggeliki', 'F', 1.0)
# ('Aggie', 'F', 0.9796057104010876)
# ('Agha', 'M', 1.0)
# ('Agigail', 'F', 1.0)
# ('Agila', 'F', 1.0)
# ('Agim', 'M', 1.0)
# ('Aginah', 'F', 1.0)
# ('Aglae', 'F', 1.0)
# ('Aglaia', 'F', 1.0)
# ('Agna', 'F', 1.0)
# ('Agneda', 'F', 1.0)
# ('Agnella', 'F', 1.0)
# ('Agnes', 'F', 0.9970530825390388)
# ('Agnesa', 'F', 1.0)
# ('Agnese', 'F', 1.0)
# ('Agness', 'F', 1.0)
# ('Agnessa', 'F', 1.0)
# ('Agneta', 'F', 1.0)
# ('Agnew', 'M', 1.0)
# ('Agnieszka', 'F', 1.0)
# ('Agnita', 'F', 1.0)
# ('Agnus', 'F', 1.0)
# ('Agostina', 'F', 1.0)
# ('Agostino', 'M', 1.0)
# ('Agrim', 'M', 1.0)
# ('Agrima', 'F', 1.0)
# ('Agripina', 'F', 1.0)
# ('Agripino', 'M', 1.0)
# ('Agron', 'M', 1.0)
# ('Agueda', 'F', 1.0)
# ('Agusta', 'F', 0.9543726235741444)
# ('Agustin', 'M', 0.998510744)
# ('Agustina', 'F', 1.0)
# ('Agustine', 'M', 1.0)
# ('Agustus', 'M', 1.0)
# ('Agustya', 'M', 1.0)
# ('Ah', 'M', 0.7789473684210526)
# ('Ahaan', 'M', 1.0)
# ('Ahaana', 'F', 1.0)
# ('Ahad', 'M', 1.0)
# ('Ahadu', 'M', 1.0)
# ('Ahalya', 'F', 1.0)
# ('Ahamad', 'M', 1.0)
# ('Ahamed', 'M', 1.0)
# ('Ahan', 'M', 1.0)
# ('Ahana', 'F', 1.0)
# ('Ahanu', 'M', 1.0)
# ('Aharon', 'M', 1.0)
# ('Aharshi', 'M', 1.0)
# ('Ahava', 'F', 1.0)
# ('Ahavah', 'F', 1.0)
# ('Ahaziah', 'M', 1.0)
# ('Ahbleza', 'M', 1.0)
# ('Ahbree', 'F', 1.0)
# ('Ahdia', 'F', 1.0)
# ('Aheli', 'F', 1.0)
# ('Ahian', 'M', 1.0)
# ('Ahijah', 'M', 1.0)
# ('Ahil', 'M', 1.0)
# ('Ahilyn', 'F', 1.0)
# ('Ahinara', 'F', 1.0)
# ('Ahir', 'M', 1.0)
# ('Ahisha', 'F', 1.0)
# ('Ahja', 'F', 1.0)
# ('Ahjah', 'F', 1.0)
# ('Ahjahnae', 'F', 1.0)
# ('Ahjanae', 'F', 1.0)
# ('Ahjanay', 'F', 1.0)
# ('Ahkai', 'M', 1.0)
# ('Ahkari', 'M', 1.0)
# ('Ahkeel', 'M', 1.0)
# ('Ahkeelah', 'F', 1.0)
# ('Ahkeem', 'M', 1.0)
# ('Ahkil', 'M', 1.0)
# ('Ahking', 'M', 1.0)
# ('Ahlaam', 'F', 1.0)
# ('Ahlai', 'F', 1.0)
# ('Ahlam', 'F', 1.0)
# ('Ahlana', 'F', 1.0)
# ('Ahlani', 'F', 1.0)
# ('Ahlanie', 'F', 1.0)
# ('Ahlanna', 'F', 1.0)
# ('Ahlaya', 'F', 1.0)
# ('Ahlayah', 'F', 1.0)
# ('Ahlayla', 'F', 1.0)
# ('Ahlayna', 'F', 1.0)
# ('Ahlaysia', 'F', 1.0)
# ('Ahlea', 'F', 1.0)
# ('Ahleah', 'F', 1.0)
# ('Ahleena', 'F', 1.0)
# ('Ahleeyah', 'F', 1.0)
# ('Ahleigha', 'F', 1.0)
# ('Ahlena', 'F', 1.0)
# ('Ahlexis', 'F', 1.0)
# ('Ahlexus', 'F', 1.0)
# ('Ahley', 'F', 1.0)
# ('Ahlia', 'F', 1.0)
# ('Ahliana', 'F', 1.0)
# ('Ahlias', 'M', 1.0)
# ('Ahlijah', 'M', 1.0)
# ('Ahlina', 'F', 1.0)
# ('Ahlivia', 'F', 1.0)
# ('Ahliya', 'F', 1.0)
# ('Ahliyah', 'F', 1.0)
# ('Ahlona', 'F', 1.0)
# ('Ahlyana', 'F', 1.0)
# ('Ahlyssa', 'F', 1.0)
# ('Ahlyvia', 'F', 1.0)
# ('Ahmaad', 'M', 1.0)
# ('Ahmad', 'M', 0.9988728866624922)
# ('Ahmadou', 'M', 1.0)
# ('Ahmaj', 'M', 1.0)
# ('Ahman', 'M', 1.0)
# ('Ahmand', 'M', 1.0)
# ('Ahmani', 'F', 0.8578088578088578)
# ('Ahmar', 'M', 1.0)
# ('Ahmara', 'F', 1.0)
# ('Ahmare', 'M', 1.0)
# ('Ahmari', 'M', 0.7065009560229446)
# ('Ahmaria', 'F', 1.0)
# ('Ahmarie', 'F', 1.0)
# ('Ahmarion', 'M', 1.0)
# ('Ahmarria', 'F', 1.0)
# ('Ahmaud', 'M', 1.0)
# ('Ahmauri', 'M', 1.0)
# ('Ahmaya', 'F', 1.0)
# ('Ahmed', 'M', 1.0)
# ('Ahmeer', 'M', 1.0)
# ('Ahmeir', 'M', 1.0)
# ('Ahmer', 'M', 1.0)
# ('Ahmere', 'M', 1.0)
# ('Ahmet', 'M', 1.0)
# ('Ahmi', 'M', 0.8837209302325582)
# ('Ahmia', 'F', 1.0)
# ('Ahmiah', 'F', 1.0)
# ('Ahmid', 'M', 1.0)
# ('Ahmier', 'M', 1.0)
# ('Ahmik', 'M', 1.0)
# ('Ahmina', 'F', 1.0)
# ('Ahmir', 'M', 0.9969040247678018)
# ('Ahmira', 'F', 1.0)
# ('Ahmiracle', 'F', 1.0)
# ('Ahmirah', 'F', 1.0)
# ('Ahmire', 'M', 1.0)
# ('Ahmiya', 'F', 1.0)
# ('Ahmiyah', 'F', 1.0)
# ('Ahmod', 'M', 1.0)
# ('Ahmon', 'M', 1.0)
# ('Ahmond', 'M', 1.0)
# ('Ahmoni', 'F', 1.0)
# ('Ahmonie', 'F', 1.0)
# ('Ahmya', 'F', 1.0)
# ('Ahmyah', 'F', 1.0)
# ('Ahmyiah', 'F', 1.0)
# ('Ahmyra', 'F', 1.0)
# ('Ahna', 'F', 1.0)
# ('Ahnaf', 'M', 1.0)
# ('Ahnah', 'F', 1.0)
# ('Ahnalee', 'F', 1.0)
# ('Ahnaleigh', 'F', 1.0)
# ('Ahnalia', 'F', 1.0)
# ('Ahnalise', 'F', 1.0)
# ('Ahnari', 'F', 1.0)
# ('Ahnaya', 'F', 1.0)
# ('Ahnesti', 'F', 1.0)
# ('Ahnesty', 'F', 1.0)
# ('Ahni', 'F', 1.0)
# ('Ahnia', 'F', 1.0)
# ('Ahniah', 'F', 1.0)
# ('Ahnika', 'F', 1.0)
# ('Ahnisty', 'F', 1.0)
# ('Ahniya', 'F', 1.0)
# ('Ahniyah', 'F', 1.0)
# ('Ahniyla', 'F', 1.0)
# ('Ahnjayla', 'F', 1.0)
# ('Ahnna', 'F', 1.0)
# ('Ahnya', 'F', 1.0)
# ('Ahnyah', 'F', 1.0)
# ('Ahnyia', 'F', 1.0)
# ('Ahnyla', 'F', 1.0)
# ('Ahnylah', 'F', 1.0)
# ('Ahona', 'F', 1.0)
# ('Ahonesti', 'F', 1.0)
# ('Ahonesty', 'F', 1.0)
# ('Ahrayah', 'F', 1.0)
# ('Ahreanna', 'F', 1.0)
# ('Ahren', 'M', 1.0)
# ('Ahri', 'F', 1.0)
# ('Ahria', 'F', 1.0)
# ('Ahriah', 'F', 1.0)
# ('Ahrian', 'M', 1.0)
# ('Ahriana', 'F', 1.0)
# ('Ahrianna', 'F', 1.0)
# ('Ahriel', 'F', 1.0)
# ('Ahriya', 'F', 1.0)
# ('Ahriyah', 'F', 1.0)
# ('Ahron', 'M', 1.0)
# ('Ahrya', 'F', 1.0)
# ('Ahsaki', 'F', 1.0)
# ('Ahsan', 'M', 1.0)
# ('Ahsen', 'M', 1.0)
# ('Ahsha', 'F', 1.0)
# ('Ahshanti', 'F', 1.0)
# ('Ahsia', 'F', 1.0)
# ('Ahsir', 'M', 1.0)
# ('Ahslee', 'F', 1.0)
# ('Ahsley', 'F', 1.0)
# ('Ahsoka', 'F', 1.0)
# ('Ahti', 'M', 1.0)
# ('Ahtyana', 'F', 1.0)
# ('Ahtziri', 'F', 1.0)
# ('Ahtziry', 'F', 1.0)
# ('Ahuva', 'F', 1.0)
# ('Ahva', 'F', 1.0)
# ('Ahvianna', 'F', 1.0)
# ('Ahyan', 'M', 1.0)
# ('Ahyana', 'F', 1.0)
# ('Ahyanna', 'F', 1.0)
# ('Ahylin', 'F', 1.0)
# ('Ahyonna', 'F', 1.0)
# ('Ahzab', 'M', 1.0)
# ('Ahzaria', 'F', 1.0)
# ('Ahzariah', 'F', 1.0)
# ('Ahzhane', 'F', 1.0)
# ('Ahzir', 'M', 1.0)
# ('Ahziyah', 'F', 1.0)
# ('Ai', 'F', 0.9696132596685084)
# ('Aia', 'F', 1.0)
# ('Aiah', 'F', 1.0)
# ('Aian', 'M', 1.0)
# ('Aiana', 'F', 1.0)
# ('Aianna', 'F', 1.0)
# ('Aibel', 'M', 1.0)
# ('Aibhilin', 'F', 1.0)
# ('Aibhlinn', 'F', 1.0)
# ('Aibileen', 'F', 1.0)
# ('Aicen', 'M', 1.0)
# ('Aicha', 'F', 1.0)
# ('Aichatou', 'F', 1.0)
# ('Aicia', 'F', 1.0)
# ('Aida', 'F', 0.999581905)
# ('Aidah', 'F', 1.0)
# ('Aidaliz', 'F', 1.0)
# ('Aidaly', 'F', 1.0)
# ('Aidalyn', 'F', 1.0)
# ('Aidan', 'M', 0.9758546229563364)
# ('Aidana', 'F', 1.0)
# ('Aidanjames', 'M', 1.0)
# ('Aidanjohn', 'M', 1.0)
# ('Aidann', 'M', 1.0)
# ('Aidar', 'M', 1.0)
# ('Aiddan', 'M', 1.0)
# ('Aidden', 'M', 1.0)
# ('Aide', 'F', 1.0)
# ('Aidean', 'M', 1.0)
# ('Aided', 'F', 1.0)
# ('Aidee', 'F', 1.0)
# ('Aideen', 'F', 0.7132352941176471)
# ('Aidel', 'F', 1.0)
# ('Aidelis', 'F', 1.0)
# ('Aideliz', 'F', 1.0)
# ('Aidelyn', 'F', 1.0)
# ('Aiden', 'M', 0.989757091799322)
# ('Aidenjames', 'M', 1.0)
# ('Aidenjoseph', 'M', 1.0)
# ('Aidenmatthew', 'M', 1.0)
# ('Aidenmichael', 'M', 1.0)
# ('Aidenn', 'M', 1.0)
# ('Aidet', 'F', 1.0)
# ('Aideth', 'F', 1.0)
# ('Aideyn', 'M', 1.0)
# ('Aidia', 'F', 1.0)
# ('Aidian', 'M', 1.0)
# ('Aidien', 'M', 1.0)
# ('Aidin', 'M', 0.9805510534846028)
# ('Aidon', 'M', 1.0)
# ('Aidrian', 'M', 1.0)
# ('Aidrianna', 'F', 1.0)
# ('Aidric', 'M', 1.0)
# ('Aidrick', 'M', 1.0)
# ('Aidrik', 'M', 1.0)
# ('Aidsa', 'F', 1.0)
# ('Aidy', 'F', 1.0)
# ('Aidyen', 'M', 1.0)
# ('Aidyn', 'M', 0.8202452387164101)
# ('Aidynn', 'M', 0.518796992)
# ('Aiedan', 'M', 1.0)
# ('Aieden', 'M', 1.0)
# ('Aiesha', 'F', 1.0)
# ('Aieshia', 'F', 1.0)
# ('Aigne', 'F', 1.0)
# ('Aigner', 'F', 1.0)
# ('Aiham', 'M', 1.0)
# ('Aiiden', 'M', 1.0)
# ('Aija', 'F', 1.0)
# ('Aijah', 'F', 1.0)
# ('Aijahlon', 'M', 1.0)
# ('Aijalon', 'M', 0.5177664974619289)
# ('Aijha', 'F', 1.0)
# ('Aika', 'F', 1.0)
# ('Aikeem', 'M', 1.0)
# ('Aiken', 'M', 1.0)
# ('Aiko', 'F', 1.0)
# ('Aila', 'F', 1.0)
# ('Ailah', 'F', 1.0)
# ('Ailaina', 'F', 1.0)
# ('Ailan', 'M', 1.0)
# ('Ailana', 'F', 1.0)
# ('Ailani', 'F', 1.0)
# ('Ailanie', 'F', 1.0)
# ('Ailanny', 'F', 1.0)
# ('Ailany', 'F', 1.0)
# ('Aile', 'F', 1.0)
# ('Ailea', 'F', 1.0)
# ('Aileah', 'F', 1.0)
# ('Ailean', 'F', 1.0)
# ('Aileana', 'F', 1.0)
# ('Ailed', 'F', 1.0)
# ('Ailee', 'F', 1.0)
# ('Aileen', 'F', 0.9998505455088924)
# ('Aileena', 'F', 1.0)
# ('Aileene', 'F', 1.0)
# ('Aileigh', 'F', 1.0)
# ('Ailen', 'F', 1.0)
# ('Ailena', 'F', 1.0)
# ('Ailene', 'F', 1.0)
# ('Aileny', 'F', 1.0)
# ('Ailet', 'F', 1.0)
# ('Aileth', 'F', 1.0)
# ('Ailey', 'F', 1.0)
# ('Aili', 'F', 1.0)
# ('Ailia', 'F', 1.0)
# ('Ailiana', 'F', 1.0)
# ('Ailie', 'F', 1.0)
# ('Ailin', 'F', 0.9942922374429224)
# ('Ailina', 'F', 1.0)
# ('Ailine', 'F', 1.0)
# ('Ailis', 'F', 1.0)
# ('Ailisa', 'F', 1.0)
# ('Ailise', 'F', 1.0)
# ('Ailish', 'F', 1.0)
# ('Ailiyah', 'F', 1.0)
# ('Ailleen', 'F', 1.0)
# ('Aillene', 'F', 1.0)
# ('Ailsa', 'F', 1.0)
# ('Ailton', 'M', 1.0)
# ('Aily', 'F', 1.0)
# ('Ailyah', 'F', 1.0)
# ('Ailyn', 'F', 1.0)
# ('Ailyne', 'F', 1.0)
# ('Ailynn', 'F', 1.0)
# ('Aima', 'F', 1.0)
# ('Aimal', 'M', 1.0)
# ('Aiman', 'M', 0.7675070028011205)
# ('Aimani', 'F', 1.0)
# ('Aimar', 'M', 0.512)
# ('Aimara', 'F', 1.0)
# ('Aime', 'F', 0.7784011220196353)
# ('Aimee', 'F', 0.9985277185299836)
# ('Aimen', 'F', 0.5806451612903226)
# ('Aimi', 'F', 1.0)
# ('Aimie', 'F', 1.0)
# ('Aimme', 'F', 1.0)
# ('Aimo', 'M', 1.0)
# ('Aimon', 'M', 1.0)
# ('Aimsley', 'F', 1.0)
# ('Aimy', 'F', 1.0)
# ('Ain', 'F', 1.0)
# ('Aina', 'F', 1.0)
# ('Ainara', 'F', 1.0)
# ('Aindrea', 'F', 1.0)
# ('Aine', 'F', 1.0)
# ('Ainesh', 'M', 1.0)
# ('Ainhara', 'F', 1.0)
# ('Ainhoa', 'F', 1.0)
# ('Aini', 'F', 1.0)
# ('Ainka', 'F', 1.0)
# ('Aino', 'F', 1.0)
# ('Ainslee', 'F', 1.0)
# ('Ainsleigh', 'F', 1.0)
# ('Ainsley', 'F', 0.974496152)
# ('Ainslie', 'F', 1.0)
# ('Ainsly', 'F', 1.0)
# ('Ainsworth', 'M', 1.0)
# ('Ainzlee', 'F', 1.0)
# ('Ainzley', 'F', 1.0)
# ('Aiona', 'F', 1.0)
# ('Aionna', 'F', 1.0)
# ('Aira', 'F', 1.0)
# ('Airabella', 'F', 1.0)
# ('Airabelle', 'F', 1.0)
# ('Airah', 'F', 1.0)
# ('Airalyn', 'F', 1.0)
# ('Airalynn', 'F', 1.0)
# ('Airam', 'F', 0.8735332464146024)
# ('Airan', 'M', 1.0)
# ('Airanna', 'F', 1.0)
# ('Aire', 'F', 1.0)
# ('Aireal', 'F', 1.0)
# ('Aireana', 'F', 1.0)
# ('Aireanna', 'F', 1.0)
# ('Aireka', 'F', 1.0)
# ('Airel', 'F', 1.0)
# ('Airelle', 'F', 1.0)
# ('Airen', 'F', 0.5421686746987951)
# ('Aireon', 'M', 0.9152542372881356)
# ('Aireona', 'F', 1.0)
# ('Aireonna', 'F', 1.0)
# ('Aires', 'M', 0.78125)
# ('Airess', 'F', 1.0)
# ('Aireyana', 'F', 1.0)
# ('Airi', 'F', 1.0)
# ('Airial', 'F', 1.0)
# ('Airian', 'F', 1.0)
# ('Airiana', 'F', 1.0)
# ('Airianna', 'F', 1.0)
# ('Airic', 'M', 1.0)
# ('Airica', 'F', 1.0)
# ('Airick', 'M', 1.0)
# ('Airicka', 'F', 1.0)
# ('Airiel', 'F', 1.0)
# ('Airielle', 'F', 1.0)
# ('Airik', 'M', 1.0)
# ('Airika', 'F', 1.0)
# ('Airin', 'F', 0.8611111111111112)
# ('Airion', 'M', 1.0)
# ('Airiona', 'F', 1.0)
# ('Airionna', 'F', 1.0)
# ('Airis', 'F', 0.9504950495049505)
# ...
# ('Zeporia', 'F', 1.0)
# ('Zeppelin', 'M', 0.924198251)
# ('Zeppelyn', 'F', 1.0)
# ('Zepplin', 'M', 1.0)
# ('Zequan', 'M', 1.0)
# ('Zer', 'F', 1.0)
# ('Zera', 'F', 0.9824253075571178)
# ('Zerah', 'F', 1.0)
# ('Zerek', 'M', 1.0)
# ('Zerelda', 'F', 1.0)
# ('Zerena', 'F', 1.0)
# ('Zerenity', 'F', 1.0)
# ('Zereon', 'M', 1.0)
# ('Zeriah', 'F', 0.9747474747474748)
# ('Zeric', 'M', 1.0)
# ('Zerick', 'M', 1.0)
# ('Zerik', 'M', 1.0)
# ('Zerin', 'M', 1.0)
# ('Zerina', 'F', 1.0)
# ('Zerion', 'M', 1.0)
# ('Zerita', 'F', 1.0)
# ('Zeriyah', 'F', 1.0)
# ('Zerlene', 'F', 1.0)
# ('Zerlina', 'F', 1.0)
# ('Zerline', 'F', 1.0)
# ('Zeron', 'M', 1.0)
# ('Zerriah', 'F', 1.0)
# ('Zerrick', 'M', 1.0)
# ('Zerrion', 'M', 1.0)
# ('Zeruiah', 'F', 1.0)
# ('Zeryk', 'M', 1.0)
# ('Zesar', 'M', 1.0)
# ('Zeshan', 'M', 1.0)
# ('Zeshaun', 'M', 1.0)
# ('Zeshawn', 'M', 1.0)
# ('Zeta', 'F', 1.0)
# ('Zeth', 'M', 1.0)
# ('Zetha', 'F', 1.0)
# ('Zethan', 'M', 1.0)
# ('Zetta', 'F', 1.0)
# ('Zettie', 'F', 0.9931880108991824)
# ('Zeus', 'M', 1.0)
# ('Zev', 'M', 1.0)
# ('Zeva', 'F', 1.0)
# ('Zevaeh', 'F', 1.0)
# ('Zevan', 'M', 1.0)
# ('Zeven', 'M', 1.0)
# ('Zevi', 'M', 1.0)
# ('Zevin', 'M', 1.0)
# ('Zevion', 'M', 1.0)
# ('Zevon', 'M', 1.0)
# ('Zevulun', 'M', 1.0)
# ('Zevyn', 'M', 1.0)
# ('Zeya', 'F', 1.0)
# ('Zeyad', 'M', 1.0)
# ('Zeyah', 'F', 1.0)
# ('Zeyana', 'F', 1.0)
# ('Zeyd', 'M', 1.0)
# ('Zeyda', 'F', 1.0)
# ('Zeyden', 'M', 1.0)
# ('Zeyla', 'F', 1.0)
# ('Zeylah', 'F', 1.0)
# ('Zeyna', 'F', 1.0)
# ('Zeynab', 'F', 1.0)
# ('Zeyneb', 'F', 1.0)
# ('Zeynep', 'F', 1.0)
# ('Zeza', 'F', 1.0)
# ('Zhaiden', 'M', 1.0)
# ('Zhair', 'M', 1.0)
# ('Zhaira', 'F', 1.0)
# ('Zhaire', 'M', 1.0)
# ('Zhaki', 'M', 1.0)
# ('Zhakira', 'F', 1.0)
# ('Zhalen', 'M', 1.0)
# ('Zhamir', 'M', 1.0)
# ('Zhana', 'F', 1.0)
# ('Zhanae', 'F', 1.0)
# ('Zhanasia', 'F', 1.0)
# ('Zhanaya', 'F', 1.0)
# ('Zhander', 'M', 1.0)
# ('Zhane', 'F', 0.874282983)
# ('Zhanea', 'F', 1.0)
# ('Zhanee', 'F', 1.0)
# ('Zhanel', 'F', 1.0)
# ('Zhanelle', 'F', 1.0)
# ('Zhania', 'F', 1.0)
# ('Zhaniya', 'F', 1.0)
# ('Zhaniyah', 'F', 1.0)
# ('Zhanna', 'F', 1.0)
# ('Zhanya', 'F', 1.0)
# ('Zhara', 'F', 1.0)
# ('Zhari', 'F', 1.0)
# ('Zharia', 'F', 1.0)
# ('Zhariah', 'F', 1.0)
# ('Zharick', 'F', 1.0)
# ('Zhariya', 'F', 1.0)
# ('Zhariyah', 'F', 1.0)
# ('Zharya', 'F', 1.0)
# ('Zharyah', 'F', 1.0)
# ('Zhayden', 'M', 1.0)
# ('Zhayne', 'M', 1.0)
# ('Zhen', 'M', 1.0)
# ('Zheneavia', 'F', 1.0)
# ('Zheng', 'M', 1.0)
# ('Zhi', 'M', 0.89375)
# ('Zhia', 'F', 1.0)
# ('Zhian', 'M', 1.0)
# ('Zhianna', 'F', 1.0)
# ('Zhion', 'M', 1.0)
# ('Zhivago', 'M', 1.0)
# ('Zhiya', 'F', 1.0)
# ('Zhoe', 'F', 1.0)
# ('Zhoey', 'F', 1.0)
# ('Zhoie', 'F', 1.0)
# ('Zhuri', 'F', 1.0)
# ('Zhyair', 'M', 1.0)
# ('Zhyaire', 'M', 1.0)
# ('Zhyier', 'M', 1.0)
# ('Zhyir', 'M', 1.0)
# ('Zhymir', 'M', 1.0)
# ('Zhyon', 'M', 0.8)
# ('Zi', 'F', 0.5135135135135135)
# ('Zia', 'F', 0.8934517203107658)
# ('Ziad', 'M', 1.0)
# ('Ziah', 'F', 0.7768313458262351)
# ('Ziair', 'M', 1.0)
# ('Ziaira', 'F', 1.0)
# ('Ziaire', 'M', 0.8525)
# ('Zian', 'M', 0.7233201581027668)
# ('Ziana', 'F', 1.0)
# ('Zianah', 'F', 1.0)
# ('Ziane', 'F', 1.0)
# ('Ziann', 'F', 1.0)
# ('Zianna', 'F', 1.0)
# ('Ziannah', 'F', 1.0)
# ('Zianne', 'F', 1.0)
# ('Zianny', 'F', 1.0)
# ('Zianya', 'F', 1.0)
# ('Ziar', 'M', 1.0)
# ('Ziara', 'F', 1.0)
# ('Ziarah', 'F', 1.0)
# ('Ziare', 'M', 0.8055555555555556)
# ('Ziarra', 'F', 1.0)
# ('Ziarre', 'F', 1.0)
# ('Ziasia', 'F', 1.0)
# ('Ziba', 'M', 1.0)
# ('Zichen', 'M', 1.0)
# ('Ziclali', 'F', 1.0)
# ('Ziclaly', 'F', 1.0)
# ('Zico', 'M', 1.0)
# ('Zida', 'F', 1.0)
# ('Zidaan', 'M', 1.0)
# ('Zidan', 'M', 1.0)
# ('Zidane', 'M', 1.0)
# ('Ziden', 'M', 1.0)
# ('Zidon', 'M', 1.0)
# ('Ziel', 'M', 0.6)
# ('Zien', 'M', 1.0)
# ('Ziena', 'F', 1.0)
# ('Zienna', 'F', 1.0)
# ('Zier', 'M', 1.0)
# ('Ziera', 'F', 1.0)
# ('Ziere', 'M', 1.0)
# ('Zierra', 'F', 1.0)
# ('Zierre', 'M', 1.0)
# ('Ziggie', 'M', 1.0)
# ('Ziggy', 'M', 0.984375)
# ('Zigmond', 'M', 1.0)
# ('Zigmont', 'M', 1.0)
# ('Zigmund', 'M', 1.0)
# ('Zigmunt', 'M', 1.0)
# ('Ziham', 'F', 1.0)
# ('Zihan', 'F', 0.5)
# ('Zihanna', 'F', 1.0)
# ('Zihao', 'M', 1.0)
# ('Ziheir', 'M', 1.0)
# ('Ziheng', 'M', 1.0)
# ('Ziion', 'M', 1.0)
# ('Zijun', 'M', 1.0)
# ('Zikayla', 'F', 1.0)
# ('Zikee', 'M', 1.0)
# ('Zikeria', 'F', 1.0)
# ('Zikeya', 'F', 1.0)
# ('Zikeyah', 'F', 1.0)
# ('Zikia', 'F', 1.0)
# ('Zikira', 'F', 1.0)
# ('Zikiria', 'F', 1.0)
# ('Zikiya', 'F', 1.0)
# ('Zikomo', 'M', 1.0)
# ('Zikora', 'M', 0.7272727272727273)
# ('Zikra', 'F', 1.0)
# ('Zila', 'F', 1.0)
# ('Zilah', 'F', 1.0)
# ('Zilas', 'M', 1.0)
# ('Zilda', 'F', 1.0)
# ('Zildjian', 'M', 1.0)
# ('Ziley', 'F', 1.0)
# ('Zilin', 'F', 1.0)
# ('Zilla', 'F', 1.0)
# ('Zillah', 'F', 1.0)
# ('Zillie', 'F', 1.0)
# ('Zilpah', 'F', 1.0)
# ('Zilpha', 'F', 1.0)
# ('Zilphia', 'F', 1.0)
# ('Zilynn', 'F', 1.0)
# ('Zim', 'M', 1.0)
# ('Zimal', 'F', 1.0)
# ('Zimaria', 'F', 1.0)
# ('Zimarion', 'M', 1.0)
# ('Zimaya', 'F', 1.0)
# ('Zimbabwe', 'M', 1.0)
# ('Zimbalist', 'M', 1.0)
# ('Zimere', 'M', 1.0)
# ('Zimir', 'M', 1.0)
# ('Zimmie', 'F', 1.0)
# ('Zimora', 'F', 1.0)
# ('Zimri', 'M', 0.9423076923076924)
# ('Zimya', 'F', 1.0)
# ('Zina', 'F', 0.9978920741989882)
# ('Zinab', 'F', 1.0)
# ('Zinachidi', 'F', 1.0)
# ('Zinachimdi', 'F', 1.0)
# ('Zinaya', 'F', 1.0)
# ('Zinda', 'F', 1.0)
# ('Zineb', 'F', 1.0)
# ('Zinedin', 'M', 1.0)
# ('Zinedine', 'M', 1.0)
# ('Zinia', 'F', 1.0)
# ('Ziniah', 'F', 1.0)
# ('Ziniya', 'F', 1.0)
# ('Ziniyah', 'F', 1.0)
# ('Zinn', 'M', 1.0)
# ('Zinna', 'F', 1.0)
# ('Zinnia', 'F', 1.0)
# ('Ziomara', 'F', 1.0)
# ('Zion', 'M', 0.8134064506818673)
# ('Ziona', 'F', 1.0)
# ('Zionah', 'F', 1.0)
# ('Zione', 'M', 1.0)
# ('Zionn', 'M', 1.0)
# ('Zionna', 'F', 1.0)
# ('Zionnah', 'F', 1.0)
# ('Zionne', 'F', 1.0)
# ('Zipora', 'F', 1.0)
# ('Ziporah', 'F', 1.0)
# ('Zipporah', 'F', 1.0)
# ('Ziqi', 'F', 1.0)
# ('Ziquan', 'M', 1.0)
# ('Zira', 'F', 1.0)
# ('Zirah', 'F', 1.0)
# ('Ziraili', 'F', 1.0)
# ('Ziraily', 'F', 1.0)
# ('Zirel', 'F', 1.0)
# ('Zirui', 'M', 1.0)
# ('Zisel', 'F', 1.0)
# ('Zishan', 'M', 1.0)
# ('Zishe', 'M', 1.0)
# ('Zissel', 'F', 1.0)
# ('Zissy', 'F', 1.0)
# ('Zita', 'F', 1.0)
# ('Zithlaly', 'F', 1.0)
# ('Zitlali', 'F', 1.0)
# ('Zitlalic', 'F', 1.0)
# ('Zitlalli', 'F', 1.0)
# ('Zitlally', 'F', 1.0)
# ('Zitlaly', 'F', 1.0)
# ('Zitong', 'F', 1.0)
# ('Ziv', 'M', 1.0)
# ('Ziva', 'F', 1.0)
# ('Zivah', 'F', 1.0)
# ('Ziven', 'M', 1.0)
# ('Zivon', 'M', 1.0)
# ('Zixi', 'F', 1.0)
# ('Zixin', 'F', 1.0)
# ('Zixuan', 'M', 0.5581395348837209)
# ('Ziya', 'F', 0.9722675367047308)
# ('Ziyaad', 'M', 1.0)
# ('Ziyad', 'M', 1.0)
# ('Ziyadah', 'F', 1.0)
# ('Ziyah', 'F', 0.9695431472081218)
# ('Ziyan', 'M', 0.5537190082644629)
# ('Ziyana', 'F', 1.0)
# ('Ziyanah', 'F', 1.0)
# ('Ziyang', 'M', 1.0)
# ('Ziyanna', 'F', 1.0)
# ('Ziyear', 'M', 1.0)
# ('Ziyi', 'F', 0.5)
# ('Ziyla', 'F', 1.0)
# ('Ziyon', 'M', 0.8356164383561644)
# ('Ziyona', 'F', 1.0)
# ('Ziyonna', 'F', 1.0)
# ('Ziyu', 'M', 1.0)
# ('Ziyun', 'M', 1.0)
# ('Ziza', 'F', 1.0)
# ('Zkai', 'M', 1.0)
# ('Zkye', 'M', 1.0)
# ('Zlata', 'F', 1.0)
# ('Zlatan', 'M', 1.0)
# ('Zlaty', 'F', 1.0)
# ('Zmari', 'M', 1.0)
# ('Zmarion', 'M', 1.0)
# ('Zmaya', 'F', 1.0)
# ('Zmiyah', 'F', 1.0)
# ('Zmya', 'F', 1.0)
# ('Zniah', 'F', 1.0)
# ('Zniya', 'F', 1.0)
# ('Zniyah', 'F', 1.0)
# ('Znya', 'F', 1.0)
# ('Znyah', 'F', 1.0)
# ('Zo', 'F', 0.8809523809523809)
# ('Zoa', 'F', 1.0)
# ('Zoann', 'F', 1.0)
# ('Zoanne', 'F', 1.0)
# ('Zobeida', 'F', 1.0)
# ('Zobia', 'F', 1.0)
# ('Zody', 'F', 1.0)
# ('Zoe', 'F', 0.9960988062706744)
# ('Zoeann', 'F', 1.0)
# ('Zoeanna', 'F', 1.0)
# ('Zoeanne', 'F', 1.0)
# ('Zoee', 'F', 1.0)
# ('Zoeey', 'F', 1.0)
# ('Zoegrace', 'F', 1.0)
# ('Zoeh', 'F', 1.0)
# ('Zoei', 'F', 1.0)
# ('Zoeie', 'F', 1.0)
# ('Zoeigh', 'F', 1.0)
# ('Zoeii', 'F', 1.0)
# ('Zoeiy', 'F', 1.0)
# ('Zoejane', 'F', 1.0)
# ('Zoel', 'M', 0.6909090909090909)
# ('Zoelie', 'F', 1.0)
# ('Zoella', 'F', 1.0)
# ('Zoelle', 'F', 1.0)
# ('Zoely', 'F', 1.0)
# ('Zoelyn', 'F', 1.0)
# ('Zoelynn', 'F', 1.0)
# ('Zoemarie', 'F', 1.0)
# ('Zoen', 'M', 1.0)
# ('Zoey', 'F', 0.9970083888477672)
# ('Zoeya', 'F', 1.0)
# ('Zoeyann', 'F', 1.0)
# ('Zoeygrace', 'F', 1.0)
# ('Zoeyjane', 'F', 1.0)
# ('Zoeylynn', 'F', 1.0)
# ('Zoeymarie', 'F', 1.0)
# ('Zofia', 'F', 1.0)
# ('Zofie', 'F', 1.0)
# ('Zoha', 'F', 1.0)
# ('Zohaib', 'M', 1.0)
# ('Zohair', 'M', 1.0)
# ('Zohal', 'F', 1.0)
# ('Zohan', 'M', 1.0)
# ('Zohar', 'F', 0.6302083333333334)
# ('Zohara', 'F', 1.0)
# ('Zohe', 'F', 1.0)
# ('Zoheb', 'M', 1.0)
# ('Zohie', 'F', 1.0)
# ('Zohra', 'F', 1.0)
# ('Zohrab', 'M', 1.0)
# ('Zoi', 'F', 1.0)
# ('Zoia', 'F', 1.0)
# ('Zoie', 'F', 1.0)
# ('Zoiee', 'F', 1.0)
# ('Zoiey', 'F', 1.0)
# ('Zoii', 'F', 1.0)
# ('Zoiie', 'F', 1.0)
# ('Zoila', 'F', 1.0)
# ('Zoilo', 'M', 1.0)
# ('Zoja', 'F', 1.0)
# ('Zola', 'F', 0.996969697)
# ('Zolah', 'F', 1.0)
# ('Zolan', 'M', 1.0)
# ('Zolar', 'F', 1.0)
# ('Zolee', 'F', 1.0)
# ('Zoli', 'F', 1.0)
# ('Zolie', 'F', 1.0)
# ('Zolin', 'M', 1.0)
# ('Zollie', 'M', 0.8599791013584117)
# ('Zoltan', 'M', 1.0)
# ('Zolton', 'M', 1.0)
# ('Zoma', 'F', 1.0)
# ('Zon', 'M', 1.0)
# ('Zona', 'F', 1.0)
# ('Zonda', 'F', 1.0)
# ('Zondra', 'F', 1.0)
# ('Zong', 'M', 0.811965812)
# ('Zonia', 'F', 1.0)
# ('Zonie', 'F', 1.0)
# ('Zonna', 'F', 1.0)
# ('Zonnie', 'F', 0.9375)
# ('Zonnique', 'F', 1.0)
# ('Zonya', 'F', 1.0)
# ('Zooey', 'F', 1.0)
# ('Zophia', 'F', 1.0)
# ('Zophie', 'F', 1.0)
# ('Zora', 'F', 0.9971525423728812)
# ('Zorah', 'F', 1.0)
# ('Zoraida', 'F', 1.0)
# ('Zoraiz', 'M', 1.0)
# ('Zoran', 'M', 1.0)
# ('Zorana', 'F', 1.0)
# ('Zoravar', 'M', 1.0)
# ('Zorawar', 'M', 1.0)
# ('Zoraya', 'F', 1.0)
# ('Zorayda', 'F', 1.0)
# ('Zoree', 'F', 1.0)
# ('Zoren', 'M', 1.0)
# ('Zori', 'F', 1.0)
# ('Zoria', 'F', 1.0)
# ('Zoriah', 'F', 1.0)
# ('Zorian', 'M', 1.0)
# ('Zoriana', 'F', 1.0)
# ('Zorianna', 'F', 1.0)
# ('Zoribel', 'F', 1.0)
# ('Zorica', 'F', 1.0)
# ('Zorie', 'F', 1.0)
# ('Zorien', 'M', 1.0)
# ('Zorina', 'F', 1.0)
# ('Zorion', 'M', 1.0)
# ('Zorita', 'F', 1.0)
# ('Zoriyah', 'F', 1.0)
# ('Zorka', 'F', 1.0)
# ('Zorria', 'F', 1.0)
# ('Zorriah', 'F', 1.0)
# ('Zory', 'F', 1.0)
# ('Zorya', 'F', 1.0)
# ('Zoryana', 'F', 1.0)
# ('Zosha', 'F', 1.0)
# ('Zosia', 'F', 1.0)
# ('Zoua', 'F', 1.0)
# ('Zowee', 'F', 1.0)
# ('Zowey', 'F', 1.0)
# ('Zowie', 'F', 1.0)
# ('Zowii', 'F', 1.0)
# ('Zoya', 'F', 1.0)
# ('Zoyah', 'F', 1.0)
# ('Zoye', 'F', 1.0)
# ('Zoyla', 'F', 1.0)
# ('Zriah', 'F', 1.0)
# ('Zriyah', 'F', 1.0)
# ('Zsa', 'F', 1.0)
# ('Zsazsa', 'F', 1.0)
# ('Zshakira', 'F', 1.0)
# ('Zsofia', 'F', 1.0)
# ('Zsolt', 'M', 1.0)
# ('Zsophia', 'F', 1.0)
# ('Zubaida', 'F', 1.0)
# ('Zubaidah', 'F', 1.0)
# ('Zubair', 'M', 1.0)
# ('Zubayr', 'M', 1.0)
# ('Zuberi', 'M', 1.0)
# ('Zubeyr', 'M', 1.0)
# ('Zubie', 'F', 1.0)
# ('Zubin', 'M', 1.0)
# ('Zudie', 'F', 1.0)
# ('Zudora', 'F', 1.0)
# ('Zuella', 'F', 1.0)
# ('Zuha', 'F', 1.0)
# ('Zuhaib', 'M', 1.0)
# ('Zuhair', 'M', 1.0)
# ('Zuhal', 'F', 1.0)
# ('Zuhayr', 'M', 1.0)
# ('Zuheily', 'F', 1.0)
# ('Zuhey', 'F', 1.0)
# ('Zuheyla', 'F', 1.0)
# ('Zuhra', 'F', 1.0)
# ('Zuhur', 'F', 1.0)
# ('Zui', 'M', 1.0)
# ('Zujeily', 'F', 1.0)
# ('Zujey', 'F', 1.0)
# ('Zuko', 'M', 1.0)
# ('Zula', 'F', 1.0)
# ('Zulai', 'F', 1.0)
# ('Zulaika', 'F', 1.0)
# ('Zular', 'F', 1.0)
# ('Zulay', 'F', 1.0)
# ('Zuleica', 'F', 1.0)
# ('Zuleidy', 'F', 1.0)
# ('Zuleika', 'F', 1.0)
# ('Zuleikha', 'F', 1.0)
# ('Zuleima', 'F', 1.0)
# ('Zuleimy', 'F', 1.0)
# ('Zulekha', 'F', 1.0)
# ('Zulema', 'F', 1.0)
# ('Zulene', 'F', 1.0)
# ('Zuley', 'F', 1.0)
# ('Zuleyca', 'F', 1.0)
# ('Zuleyka', 'F', 1.0)
# ('Zuleyma', 'F', 1.0)
# ('Zuleymi', 'F', 1.0)
# ('Zuli', 'F', 1.0)
# ('Zulia', 'F', 1.0)
# ('Zuliana', 'F', 1.0)
# ('Zulie', 'F', 1.0)
# ('Zulimar', 'F', 1.0)
# ('Zulla', 'F', 1.0)
# ('Zully', 'F', 1.0)
# ('Zulma', 'F', 1.0)
# ('Zulmarie', 'F', 1.0)
# ('Zulmira', 'F', 1.0)
# ('Zulmy', 'F', 1.0)
# ('Zuly', 'F', 1.0)
# ('Zuma', 'F', 1.0)
# ('Zunaira', 'F', 1.0)
# ('Zunairah', 'F', 1.0)
# ('Zunilda', 'F', 1.0)
# ('Zura', 'F', 1.0)
# ('Zuree', 'F', 1.0)
# ('Zuri', 'F', 0.9029796511627908)
# ('Zuria', 'F', 1.0)
# ('Zuriah', 'F', 0.9629629629629628)
# ('Zuriana', 'F', 1.0)
# ('Zurianna', 'F', 1.0)
# ('Zurich', 'M', 1.0)
# ('Zurie', 'F', 1.0)
# ('Zuriel', 'M', 0.8428005284015853)
# ('Zuriela', 'F', 1.0)
# ('Zurielle', 'F', 1.0)
# ('Zurii', 'F', 1.0)
# ('Zurina', 'F', 1.0)
# ('Zurisadai', 'F', 1.0)
# ('Zurisaday', 'F', 1.0)
# ('Zuriya', 'F', 1.0)
# ('Zuriyah', 'F', 1.0)
# ('Zurri', 'F', 1.0)
# ('Zury', 'F', 1.0)
# ('Zuszeth', 'F', 1.0)
# ('Zuwena', 'F', 1.0)
# ('Zuzana', 'F', 1.0)
# ('Zuzanna', 'F', 1.0)
# ('Zuzu', 'F', 1.0)
# ('Zvi', 'M', 1.0)
# ('Zxavian', 'M', 1.0)
# ('Zy', 'M', 0.85)
# ('Zya', 'F', 1.0)
# ('Zyad', 'M', 1.0)
# ('Zyah', 'F', 0.98015873015873)
# ('Zyahna', 'F', 1.0)
# ('Zyair', 'M', 0.883495146)
# ('Zyaira', 'F', 1.0)
# ('Zyairah', 'F', 1.0)
# ('Zyaire', 'M', 0.7948602344454464)
# ('Zyairr', 'M', 1.0)
# ('Zyairra', 'F', 1.0)
# ('Zyan', 'M', 0.7374245472837022)
# ('Zyana', 'F', 1.0)
# ('Zyanah', 'F', 1.0)
# ('Zyani', 'F', 1.0)
# ('Zyann', 'F', 1.0)
# ('Zyanna', 'F', 1.0)
# ('Zyannah', 'F', 1.0)
# ('Zyanne', 'F', 1.0)
# ('Zyanya', 'F', 1.0)
# ('Zyara', 'F', 1.0)
# ('Zyarah', 'F', 1.0)
# ('Zyare', 'M', 1.0)
# ('Zyaria', 'F', 1.0)
# ('Zyariah', 'F', 1.0)
# ('Zyashia', 'F', 1.0)
# ('Zyasia', 'F', 1.0)
# ('Zyaun', 'M', 1.0)
# ('Zyauna', 'F', 1.0)
# ('Zyda', 'F', 1.0)
# ('Zydarius', 'M', 1.0)
# ('Zyden', 'M', 1.0)
# ('Zydia', 'F', 1.0)
# ('Zye', 'M', 1.0)
# ('Zyeer', 'M', 1.0)
# ('Zyeir', 'M', 1.0)
# ('Zyeire', 'M', 1.0)
# ('Zyel', 'M', 1.0)
# ('Zyell', 'M', 1.0)
# ('Zyelle', 'F', 1.0)
# ('Zyen', 'M', 1.0)
# ('Zyera', 'F', 1.0)
# ('Zyere', 'M', 1.0)
# ('Zyeria', 'F', 1.0)
# ('Zyerre', 'M', 1.0)
# ('Zyesha', 'F', 1.0)
# ('Zygmond', 'M', 1.0)
# ('Zygmont', 'M', 1.0)
# ('Zygmund', 'M', 1.0)
# ('Zygmunt', 'M', 1.0)
# ('Zyhaire', 'M', 1.0)
# ('Zyheem', 'M', 1.0)
# ('Zyheim', 'M', 1.0)
# ('Zyheir', 'M', 1.0)
# ('Zyhier', 'M', 1.0)
# ('Zyhir', 'M', 1.0)
# ('Zyia', 'F', 1.0)
# ('Zyiah', 'F', 1.0)
# ('Zyian', 'F', 0.5833333333333334)
# ('Zyiana', 'F', 1.0)
# ('Zyianna', 'F', 1.0)
# ('Zyien', 'M', 0.8181818181818182)
# ('Zyier', 'M', 1.0)
# ('Zyiere', 'M', 1.0)
# ('Zyin', 'M', 1.0)
# ('Zyion', 'M', 0.8347305389221557)
# ('Zyiona', 'F', 1.0)
# ('Zyionna', 'F', 1.0)
# ('Zyir', 'M', 1.0)
# ('Zyira', 'F', 1.0)
# ('Zyire', 'M', 1.0)
# ('Zykaria', 'F', 1.0)
# ('Zykayla', 'F', 1.0)
# ('Zykee', 'M', 1.0)
# ('Zykeem', 'M', 1.0)
# ('Zykei', 'M', 1.0)
# ('Zykeia', 'F', 1.0)
# ('Zykeira', 'F', 1.0)
# ('Zykeith', 'M', 1.0)
# ('Zykel', 'M', 1.0)
# ('Zykell', 'M', 1.0)
# ('Zykera', 'F', 1.0)
# ('Zykeria', 'F', 1.0)
# ('Zykeriah', 'F', 1.0)
# ('Zykerion', 'M', 1.0)
# ('Zykeriya', 'F', 1.0)
# ('Zykerria', 'F', 1.0)
# ('Zykerriah', 'F', 1.0)
# ('Zykevious', 'M', 1.0)
# ('Zykia', 'F', 1.0)
# ('Zykiah', 'F', 1.0)
# ('Zykiera', 'F', 1.0)
# ('Zykierra', 'F', 1.0)
# ('Zyking', 'M', 1.0)
# ('Zykir', 'M', 1.0)
# ('Zykira', 'F', 1.0)
# ('Zykirah', 'F', 1.0)
# ('Zykiria', 'F', 1.0)
# ('Zyla', 'F', 1.0)
# ('Zylah', 'F', 1.0)
# ('Zylan', 'M', 1.0)
# ('Zylar', 'M', 1.0)
# ('Zylas', 'M', 1.0)
# ('Zyleah', 'F', 1.0)
# ('Zylee', 'F', 1.0)
# ('Zyleigh', 'F', 1.0)
# ('Zylen', 'M', 1.0)
# ('Zyler', 'M', 1.0)
# ('Zylia', 'F', 1.0)
# ('Zyliah', 'F', 1.0)
# ('Zylie', 'F', 1.0)
# ('Zylin', 'M', 1.0)
# ('Zylis', 'M', 1.0)
# ('Zyliyah', 'F', 1.0)
# ('Zyllah', 'F', 1.0)
# ('Zylon', 'M', 1.0)
# ('Zylpha', 'F', 1.0)
# ('Zylphia', 'F', 1.0)
# ('Zylynn', 'F', 1.0)
# ('Zymair', 'M', 1.0)
# ('Zymaire', 'M', 1.0)
# ('Zymal', 'F', 1.0)
# ('Zymari', 'M', 1.0)
# ('Zymaria', 'F', 1.0)
# ('Zymarion', 'M', 1.0)
# ('Zymeer', 'M', 1.0)
# ('Zymeir', 'M', 1.0)
# ('Zymeire', 'M', 1.0)
# ('Zymere', 'M', 1.0)
# ('Zymeria', 'F', 1.0)
# ('Zymia', 'F', 1.0)
# ('Zymiah', 'F', 1.0)
# ('Zymier', 'M', 1.0)
# ('Zymiere', 'M', 1.0)
# ('Zymir', 'M', 1.0)
# ('Zymira', 'F', 1.0)
# ('Zymirah', 'F', 1.0)
# ('Zymire', 'M', 1.0)
# ('Zymya', 'F', 1.0)
# ('Zynab', 'F', 1.0)
# ('Zynae', 'F', 1.0)
# ('Zynah', 'F', 1.0)
# ('Zynaria', 'F', 1.0)
# ('Zynasia', 'F', 1.0)
# ('Zyndall', 'M', 1.0)
# ('Zynia', 'F', 1.0)
# ('Zyniah', 'F', 1.0)
# ('Zynique', 'F', 1.0)
# ('Zyniya', 'F', 1.0)
# ('Zyniyah', 'F', 1.0)
# ('Zynovia', 'F', 1.0)
# ('Zyon', 'M', 0.7980182926829268)
# ('Zyona', 'F', 1.0)
# ('Zyonah', 'F', 1.0)
# ('Zyonn', 'M', 1.0)
# ('Zyonna', 'F', 1.0)
# ('Zyonnah', 'F', 1.0)
# ('Zyonne', 'M', 1.0)
# ('Zyquan', 'M', 1.0)
# ('Zyquarius', 'M', 1.0)
# ('Zyquavion', 'M', 1.0)
# ('Zyquavious', 'M', 1.0)
# ('Zyquez', 'M', 1.0)
# ('Zyra', 'F', 1.0)
# ('Zyrah', 'F', 1.0)
# ('Zyran', 'M', 1.0)
# ('Zyree', 'M', 0.7866666666666666)
# ('Zyreion', 'M', 1.0)
# ('Zyrek', 'M', 1.0)
# ('Zyrell', 'M', 1.0)
# ('Zyren', 'M', 1.0)
# ('Zyreon', 'M', 1.0)
# ('Zyrese', 'M', 1.0)
# ('Zyrhiana', 'F', 1.0)
# ('Zyri', 'F', 1.0)
# ('Zyria', 'F', 1.0)
# ('Zyriah', 'F', 1.0)
# ('Zyrian', 'M', 1.0)
# ('Zyriana', 'F', 1.0)
# ('Zyrianna', 'F', 1.0)
# ('Zyrie', 'F', 1.0)
# ('Zyriel', 'F', 1.0)
# ('Zyrielle', 'F', 1.0)
# ('Zyrihanna', 'F', 1.0)
# ('Zyrin', 'M', 1.0)
# ('Zyrion', 'M', 1.0)
# ('Zyriyah', 'F', 1.0)
# ('Zyron', 'M', 1.0)
# ('Zyrus', 'M', 1.0)
# ('Zysean', 'M', 1.0)
# ('Zyshaun', 'M', 1.0)
# ('Zyshawn', 'M', 1.0)
# ('Zyshon', 'M', 1.0)
# ('Zyshonne', 'M', 1.0)
# ('Zytaevius', 'M', 1.0)
# ('Zytaveon', 'M', 1.0)
# ('Zytavion', 'M', 1.0)
# ('Zytavious', 'M', 1.0)
# ('Zyus', 'M', 1.0)
# ('Zyvion', 'M', 1.0)
# ('Zyvon', 'M', 1.0)
# ('Zyyanna', 'F', 1.0)
# ('Zyyon', 'M', 1.0)
# ('Zzyzx', 'M', 1.0)
# ('undefined', 'F', nan)
# ('srivani', 'F')
# ('alex', 'M')
# ('monica', 'F')
# ('rajesh', 'M')
# ('shivani', 'F')

# %% [markdown]
# The class distribution shows a significant imbalance between the two classes: `0` (female) has **60,307 instances**, while `1` (male) has **34,724 instances**. This imbalance can explain why the model is predominantly predicting one class (class `0`), as shown by the confusion matrix, which is not capturing any of the male instances (`1`).
#
# ### Action Plan:
#
# 1. **Imbalance Handling:**
#    - The class imbalance is likely causing the model to focus on predicting the majority class (class `0`). The accuracy of 63.37% indicates that the model is correctly predicting the majority class but completely failing to predict the minority class (`1`).
#
#    To mitigate this, you should:
#
#    - **Use `class_weight="balanced"` in the `DecisionTreeClassifier`** to account for the imbalance:
#      ```python
#      self.model = DecisionTreeClassifier(class_weight="balanced")
#      ```
#      This assigns higher weights to the minority class to force the model to learn both classes better.
#
#    - **Try resampling techniques**:
#      - **Oversampling** the minority class (`1`) or **undersampling** the majority class (`0`).
#      - Libraries like `imbalanced-learn` can help with oversampling (`SMOTE`) or undersampling:
#        ```bash
#        pip install imbalanced-learn
#        ```
#        Example of using SMOTE:
#        ```python
#        from imblearn.over_sampling import SMOTE
#
#        smote = SMOTE(random_state=42)
#        X_resampled, y_resampled = smote.fit_resample(X_train, y_train)
#        ```
#
# 2. **Check the Model's Ability to Generalize**:
#    - **Training accuracy of 100%** indicates that your model is overfitting to the training data. Decision trees tend to overfit, especially with imbalanced data.
#      - Try limiting the depth of the tree:
#        ```python
#        self.model = DecisionTreeClassifier(max_depth=10, class_weight="balanced")
#        ```
#      - This reduces overfitting by forcing the tree to make more generalized splits.
#
# 3. **Alternative Models**:
#    - **Logistic Regression**: Since decision trees are sensitive to data imbalances and overfitting, switching to a simpler, regularized model such as logistic regression might help improve generalization and handle imbalance more effectively. You can uncomment and use logistic regression:
#      ```python
#      from sklearn.linear_model import LogisticRegression
#      self.model = LogisticRegression(class_weight="balanced")
#      ```
#
# 4. **Evaluation Metrics Beyond Accuracy**:
#    - With imbalanced data, **accuracy** is not the best measure. Instead, use metrics such as **precision**, **recall**, and **F1-score**, especially for the minority class. You can compute them with:
#      ```python
#      from sklearn.metrics import classification_report
#
#      print(classification_report(y_test, y_pred))
#      ```
#
# ### Updated Training Function Example:
# ```python
# def train(self, train_raw_data):
#     """Train the model with provided raw data."""
#     self.train_raw_data = train_raw_data
#     names, genders = zip(*train_raw_data)
#     gender_map = {"M": 1, "F": 0}  # Map gender labels to numerical values
#     y = np.array([gender_map[gender] for gender in genders])
#     X = self.vectorizer.fit_transform(names)
#
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
#     # Use class_weight="balanced" to address imbalance
#     self.model = DecisionTreeClassifier(class_weight="balanced", max_depth=10)
#
#     self.model.fit(X_train, y_train)
#     y_pred = self.model.predict(X_test)
#
#     # Print Accuracy and other metrics
#     print("Accuracy: ", accuracy_score(y_test, y_pred))
#     print("Training Accuracy: {:.2f}% ".format(self.model.score(X_train, y_train) * 100))
#     print("Testing Accuracy: {:.2f}% ".format(self.model.score(X_test, y_test) * 100))
#
#     # Confusion matrix and classification report
#     print(f"Confusion matrix: \n{confusion_matrix(y_test, y_pred)}")
#     print(classification_report(y_test, y_pred))
#
#     self.is_trained = True
# ```
#
# Try these suggestions and let me know how the performance changes!

# %%
# # Dumping csv data to pkl

# import pandas as pd
# import pickle

# # Load data from name_gender.csv
# data = pd.read_csv('name_gender.csv')

# # Save data to train_raw_data.pkl
# with open('gender_data.pkl', 'wb') as f:
#     pickle.dump(data, f)
